# %%
######## snakemake preamble start (automatically inserted, do not edit) ########
import sys; sys.path.extend(['/netscratch/dep_mercier/grp_schneeberger/bin/bin_matt/conda_envs/snakemake8/lib/python3.12/site-packages', '/netscratch/dep_mercier/grp_schneeberger/projects/Athal/Matt_snRNAseq_analysis/diploid_starsolo_pipeline/pipeline/../rules', '/netscratch/dep_mercier/grp_schneeberger/projects/Athal/Matt_snRNAseq_analysis/diploid_starsolo_pipeline/pipeline', '/netscratch/dep_mercier/grp_schneeberger/bin/bin_matt/conda_envs/snakemake8/bin', '/netscratch/dep_mercier/grp_schneeberger/bin/bin_matt/conda_envs/snakemake8/lib/python3.12', '/netscratch/dep_mercier/grp_schneeberger/bin/bin_matt/conda_envs/snakemake8/lib/python3.12/lib-dynload', '/netscratch/dep_mercier/grp_schneeberger/bin/bin_matt/conda_envs/snakemake8/lib/python3.12/site-packages', '/netscratch/dep_mercier/grp_schneeberger/projects/Athal/Matt_snRNAseq_analysis/diploid_starsolo_pipeline/rules/notebook_templates']); import pickle; snakemake = pickle.loads(b'\x80\x04\x95f\r\x00\x00\x00\x00\x00\x00\x8c\x10snakemake.script\x94\x8c\tSnakemake\x94\x93\x94)\x81\x94}\x94(\x8c\x05input\x94\x8c\x0csnakemake.io\x94\x8c\nInputFiles\x94\x93\x94)\x81\x94(\x8c\x1fcb_genotypes/col0xmany.geno.tsv\x94\x8c2cb_crossovers/col0xmany.col0__vs__db1.cb_stats.tsv\x94\x8c3cb_crossovers/col0xmany.col0__vs__kar1.cb_stats.tsv\x94\x8c9cb_crossovers/col0xmany.col0__vs__rubezhnoe1.cb_stats.tsv\x94\x8c2cb_crossovers/col0xmany.col0__vs__ms0.cb_stats.tsv\x94\x8c3cb_crossovers/col0xmany.col0__vs__tsu0.cb_stats.tsv\x94\x8c2cb_crossovers/col0xmany.col0__vs__db1.co_probs.tsv\x94\x8c3cb_crossovers/col0xmany.col0__vs__kar1.co_probs.tsv\x94\x8c9cb_crossovers/col0xmany.col0__vs__rubezhnoe1.co_probs.tsv\x94\x8c2cb_crossovers/col0xmany.col0__vs__ms0.co_probs.tsv\x94\x8c3cb_crossovers/col0xmany.col0__vs__tsu0.co_probs.tsv\x94e}\x94(\x8c\x06_names\x94}\x94(\x8c\x04geno\x94K\x00N\x86\x94\x8c\x08cb_stats\x94K\x01K\x06\x86\x94\x8c\x08co_probs\x94K\x06K\x0b\x86\x94u\x8c\x12_allowed_overrides\x94]\x94(\x8c\x05index\x94\x8c\x04sort\x94eh \x8c\tfunctools\x94\x8c\x07partial\x94\x93\x94h\x06\x8c\x19Namedlist._used_attribute\x94\x93\x94\x85\x94R\x94(h&)}\x94\x8c\x05_name\x94h sNt\x94bh!h$h&\x85\x94R\x94(h&)}\x94h*h!sNt\x94bh\x18h\nh\x1ah\x06\x8c\tNamedlist\x94\x93\x94)\x81\x94(h\x0bh\x0ch\rh\x0eh\x0fe}\x94(h\x16}\x94h\x1e]\x94(h h!eh h$h&\x85\x94R\x94(h&)}\x94h*h sNt\x94bh!h$h&\x85\x94R\x94(h&)}\x94h*h!sNt\x94bubh\x1ch1)\x81\x94(h\x10h\x11h\x12h\x13h\x14e}\x94(h\x16}\x94h\x1e]\x94(h h!eh h$h&\x85\x94R\x94(h&)}\x94h*h sNt\x94bh!h$h&\x85\x94R\x94(h&)}\x94h*h!sNt\x94bubub\x8c\x06output\x94h\x06\x8c\x0bOutputFiles\x94\x93\x94)\x81\x94\x8c\x16cb_stats/col0xmany.tsv\x94a}\x94(h\x16}\x94\x8c\x05stats\x94K\x00N\x86\x94sh\x1e]\x94(h h!eh h$h&\x85\x94R\x94(h&)}\x94h*h sNt\x94bh!h$h&\x85\x94R\x94(h&)}\x94h*h!sNt\x94bhQhNub\x8c\x06params\x94h\x06\x8c\x06Params\x94\x93\x94)\x81\x94(X\x13\x01\x00\x00cb_crossovers/col0xmany.col0__vs__db1.cb_stats.tsv -s cb_crossovers/col0xmany.col0__vs__kar1.cb_stats.tsv -s cb_crossovers/col0xmany.col0__vs__rubezhnoe1.cb_stats.tsv -s cb_crossovers/col0xmany.col0__vs__ms0.cb_stats.tsv -s cb_crossovers/col0xmany.col0__vs__tsu0.cb_stats.tsv\x94X\x13\x01\x00\x00cb_crossovers/col0xmany.col0__vs__db1.co_probs.tsv -p cb_crossovers/col0xmany.col0__vs__kar1.co_probs.tsv -p cb_crossovers/col0xmany.col0__vs__rubezhnoe1.co_probs.tsv -p cb_crossovers/col0xmany.col0__vs__ms0.co_probs.tsv -p cb_crossovers/col0xmany.col0__vs__tsu0.co_probs.tsv\x94\x8c"-g cb_genotypes/col0xmany.geno.tsv\x94e}\x94(h\x16}\x94(\x8c\nstats_flag\x94K\x00N\x86\x94\x8c\nprobs_flag\x94K\x01N\x86\x94\x8c\tgeno_flag\x94K\x02N\x86\x94uh\x1e]\x94(h h!eh h$h&\x85\x94R\x94(h&)}\x94h*h sNt\x94bh!h$h&\x85\x94R\x94(h&)}\x94h*h!sNt\x94bheh`hghahihbub\x8c\twildcards\x94h\x06\x8c\tWildcards\x94\x93\x94)\x81\x94\x8c\tcol0xmany\x94a}\x94(h\x16}\x94\x8c\x04cond\x94K\x00N\x86\x94sh\x1e]\x94(h h!eh h$h&\x85\x94R\x94(h&)}\x94h*h sNt\x94bh!h$h&\x85\x94R\x94(h&)}\x94h*h!sNt\x94b\x8c\x04cond\x94hxub\x8c\x07threads\x94K\x05\x8c\tresources\x94h\x06\x8c\tResources\x94\x93\x94)\x81\x94(K\x05K\x01\x8c\x08/scratch\x94M\x10\'MA%\x8c\x07ioheavy\x94e}\x94(h\x16}\x94(\x8c\x06_cores\x94K\x00N\x86\x94\x8c\x06_nodes\x94K\x01N\x86\x94\x8c\x06tmpdir\x94K\x02N\x86\x94\x8c\x06mem_mb\x94K\x03N\x86\x94\x8c\x07mem_mib\x94K\x04N\x86\x94\x8c\x05queue\x94K\x05N\x86\x94uh\x1e]\x94(h h!eh h$h&\x85\x94R\x94(h&)}\x94h*h sNt\x94bh!h$h&\x85\x94R\x94(h&)}\x94h*h!sNt\x94bh\x90K\x05h\x92K\x01h\x94h\x8ch\x96M\x10\'h\x98MA%h\x9ah\x8dub\x8c\x03log\x94h\x06\x8c\x03Log\x94\x93\x94)\x81\x94}\x94(h\x16}\x94h\x1e]\x94(h h!eh h$h&\x85\x94R\x94(h&)}\x94h*h sNt\x94bh!h$h&\x85\x94R\x94(h&)}\x94h*h!sNt\x94bub\x8c\x06config\x94}\x94(\x8c\x12reference_genotype\x94\x8c\x04col0\x94\x8c\x08datasets\x94}\x94(\x8c\tcol0xmany\x94}\x94(\x8c\x12reference_genotype\x94\x8c\x04col0\x94\x8c\x12parent2_accessions\x94]\x94(\x8c\x03db1\x94\x8c\x04kar1\x94\x8c\nrubezhnoe1\x94\x8c\x03ms0\x94\x8c\x04tsu0\x94eu\x8c\x08col0xdb1\x94}\x94(\x8c\x12reference_genotype\x94\x8c\x04col0\x94\x8c\x12parent2_accessions\x94]\x94\x8c\x03db1\x94au\x8c\x08db1xcol0\x94}\x94(\x8c\x12reference_genotype\x94\x8c\x03db1\x94\x8c\x12parent2_accessions\x94]\x94\x8c\x04col0\x94auu\x8c\x10genome_fasta_fns\x94}\x94(\x8c\x04col0\x94\x8c\x19../annotations/col0_cc.fa\x94\x8c\x03db1\x94\x8c\x15../annotations/db1.fa\x94\x8c\x04kar1\x94\x8c\x16../annotations/kar1.fa\x94\x8c\nrubezhnoe1\x94\x8c\x1c../annotations/rubezhnoe1.fa\x94\x8c\x03ms0\x94\x8c\x15../annotations/ms0.fa\x94\x8c\x04tsu0\x94\x8c\x16../annotations/tsu0.fa\x94u\x8c\x07gtf_fns\x94}\x94(\x8c\x04col0\x94\x8c\x1a../annotations/col0_cc.gtf\x94\x8c\x03db1\x94\x8c\x16../annotations/db1.gtf\x94u\x8c\x11barcode_whitelist\x94\x8c#../annotations/3M-february-2018.txt\x94\x8c\x1aorganellar_genome_fasta_fn\x94\x8c\x1c../annotations/organellar.fa\x94\x8c\x11organellar_gtf_fn\x94\x8c\x1d../annotations/organellar.gtf\x94u\x8c\x04rule\x94\x8c\x0cget_cb_stats\x94\x8c\x0fbench_iteration\x94N\x8c\tscriptdir\x94\x8c\x81/netscratch/dep_mercier/grp_schneeberger/projects/Athal/Matt_snRNAseq_analysis/diploid_starsolo_pipeline/rules/notebook_templates\x94ub.'); from snakemake.logging import logger; logger.printshellcmds = True; import os; os.chdir(r'/netscratch/dep_mercier/grp_schneeberger/projects/Athal/Matt_snRNAseq_analysis/diploid_starsolo_pipeline/pipeline');
######## snakemake preamble end #########

# %%
import sys
import os
import re
from glob import glob
import random
import itertools as it
import warnings
from collections import Counter, defaultdict

import numpy as np
import pandas as pd
from scipy import stats
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from sklearn.decomposition import PCA
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_predict
from sklearn.cluster import KMeans
from sklearn.mixture import GaussianMixture
import seaborn as sns

import pomegranate as pm

sys.path.extend([os.path.abspath('../scripts/')])

from singlecell_snptools.exprs import read_mmformat, lognormalise_exprs

## Default plotting params

# %matplotlib inline
sns.set(font='Arial')
plt.rcParams['svg.fonttype'] = 'none'
style = sns.axes_style('white')
style.update(sns.axes_style('ticks'))
style['xtick.major.size'] = 1
style['ytick.major.size'] = 1
sns.set(font_scale=1, style=style)
pal = sns.color_palette(['#0072b2', '#d55e00', '#009e73', '#f0e442', '#cc79a7', '#56b4e9', '#e69f00'])
cmap = ListedColormap(pal.as_hex())
sns.set_palette(pal)
sns.palplot(pal)
plt.show()

# %%
def read_cb_stats(geno_fn, co_stats_fns, hap_probs_fns, haplotype_uncertainty_percentile=75):
    if geno_fn is not None:
        geno = pd.read_csv(
            geno_fn,
            sep='\t',
            header=0,
            names=['cb', 'geno', 'nsnps', 'geno_logprob'],
            index_col='cb',
        )
        geno['nsnps'] = np.log10(geno.nsnps)
    else:
        geno = None
    co = []
    for fn in co_stats_fns:
        co.append(
            pd.read_csv(fn,
                        sep='\t',
                        index_col=['cb'],
                        usecols=[1, 2, 3],
                        names=['cb', 'nmarkers', 'hmm_score'],
                        header=0)
            )
    co = pd.concat(co, axis=0)
    co['nmarkers'] = np.log10(co.nmarkers)
    co['hmm_score'] = np.minimum(-np.log2(1 - co.hmm_score), 10)

    hap_probs = pd.concat((
        pd.read_csv(fn, sep='\t', header=[0, 1], index_col=[0, 1])
        for fn in hap_probs_fns
    ), axis=0)
    hap_probs.index = hap_probs.index.droplevel('fn_idx')

    # Since ambient DNA or doublet contamination is more likely to come from Col-0, 
    # we can use mean haplotype as a filtering metric
    co['mean_hap'] = hap_probs.mean(axis=1)

    # use the area under the absolute uncertainty line to estimate overall uncertainty
    hap_uncertainty = (hap_probs - (hap_probs > 0.5)).abs()
    co['hap_uncertainty'] = np.maximum(
        np.log10(hap_uncertainty.groupby(level=0, axis=1).agg(np.trapz, axis=1).sum(axis=1)),
        0
    )

    co_probs = (hap_probs.groupby(level=0, axis=1)
                         .diff(1, axis=1)
                         .abs()
                         .dropna(axis=1))
    co['n_crossovers'] = co_probs.sum(axis=1)

    return geno.join(co) if geno is not None else co, hap_probs

# %%
cb_stats, hap_probs = read_cb_stats(
    snakemake.input.geno,
    snakemake.input.cb_stats,
    snakemake.input.co_probs,
)

# %%
pp = sns.pairplot(
    data=cb_stats.sample(1000),
    x_vars=['nmarkers', 'geno_logprob', 'hmm_score', 'hap_uncertainty', 'mean_hap', 'n_crossovers'],
    y_vars=['nmarkers', 'geno_logprob', 'hmm_score', 'hap_uncertainty', 'mean_hap', 'n_crossovers'],
    kind='kde',
    diag_kind='kde',
    plot_kws={'common_norm': False},
    diag_kws={'common_norm': True}
)

plt.tight_layout()
#plt.savefig(os.path.join(snakemake.output[0], 'cb_stats_pairplot.svg'))
plt.show()

# %%
USESTATS = [
    'nmarkers', 'hmm_score', 'hap_uncertainty', 'mean_hap'
]

def cluster_hq_barcodes(barcode_stats, init_geno_percentile=25, stat_names=USESTATS):
    # good cells should in general have high geno probs
    init_label = barcode_stats.groupby('geno', group_keys=False, sort=False).apply(
        lambda g: (g.geno_logprob >= np.percentile(g.geno_logprob, init_geno_percentile)).astype(int)
    )
    print(init_label.value_counts())
    barcode_stats = barcode_stats.copy()[stat_names]
    dists = []
    for i in (0, 1):
        X_i = barcode_stats.loc[init_label == i]
        dists.append(pm.IndependentComponentsDistribution([
            pm.NormalDistribution(X_i[sn].mean(), X_i[sn].std())
            for sn in stat_names
        ]))
    _, w = np.unique(init_label, return_counts=True)
    gmm = pm.GeneralMixtureModel(dists, weights= w / w.sum())
    gmm.fit(barcode_stats.values, inertia=0.9)
    pred = gmm.predict(barcode_stats.values)
    prob = gmm.predict_proba(barcode_stats.values)[:, 1]
    pred = pd.Series(pred, index=barcode_stats.index, name='cluster').map({0: 'artefact', 1: 'hq'})
    prob = pd.Series(prob, index=barcode_stats.index, name='prob_hq')
    print(pred.value_counts())
    return pred, prob


def cluster_hq_barcodes_rf(barcode_stats, init_geno_percentile=25, stat_names=USESTATS):
    barcode_stats = barcode_stats.sort_index()
    # good cells should in general have high geno probs
    init_label = barcode_stats.groupby('geno', group_keys=False, sort=False).apply(
        lambda g: (g.geno_logprob >= np.percentile(g.geno_logprob, init_geno_percentile)).astype(int)
    )
    init_label = init_label.sort_index()
    print(init_label.value_counts())
    barcode_stats = barcode_stats.copy()[stat_names]
    rf = RandomForestClassifier(n_estimators=100, min_samples_leaf=50, max_depth=5)
    prob = cross_val_predict(rf, barcode_stats, init_label, cv=5, method='predict_proba')[:, 1]
    prob = pd.Series(prob, index=barcode_stats.index, name='prob_hq')
    return prob

# %%
cb_stats['prob_hq'] = cluster_hq_barcodes_rf(cb_stats)
# Out:
# geno_logprob
# 1    1384
# 0     463
# Name: count, dtype: int64

# %%
sns.histplot(x='prob_hq',
             hue='geno',
             data=cb_stats,
             bins=100,
             cumulative=True,
             stat='density',
             common_norm=False,
             element='step')
# Out:
# <Axes: xlabel='prob_hq', ylabel='Density'>

# %%
cb_stats['cluster'] = (cb_stats.prob_hq > 0.5).map({True: 'hq', False: 'artefact'})

# %%
cb_stats.cluster.value_counts()
# Out:
# cluster
# hq          1596
# artefact     251
# Name: count, dtype: int64

# %%
sns.lmplot(
    x='nmarkers',
    y='n_crossovers',
    data=cb_stats.query('cluster == "hq"'),
    lowess=True,
    scatter_kws=dict(alpha=0.25, s=5)
)
plt.show()

# %%
snakemake.input.exprs = glob('aligned_data/diploid/col0xmany.col0__vs__*_genecounts/')

# %%
count_mat = read_mmformat(
    snakemake.input.exprs,
    cb_stats.query('cluster == "hq"').index.tolist()
)
exprs_mat, sf = lognormalise_exprs(count_mat)

# %%
def doublet_detection(exprs_mat, n_clusters, n_components=2):
    pca = PCA(n_components=n_components, svd_solver='arpack')
    pca_proj = pca.fit_transform(exprs_mat.T)
    init_clusters = KMeans(n_clusters).fit_predict(pca_proj)
    _, cluster_counts = np.unique(init_clusters, return_counts=True)
    n_syn_doublets = min(cluster_counts) // 2

    syn_doublets = []
    for i in range(n_clusters):
        syn_idx = np.random.choice(np.argwhere(init_clusters == i).squeeze(), size=n_syn_doublets, replace=True)
        syn_doublets.append(exprs_mat.iloc[:, syn_idx])
    syn_doublets = np.average(syn_doublets, axis=0, )
    syn_doublet_pca_proj = pca.transform(syn_doublets.T)
    knn = KNeighborsClassifier(n_neighbors=n_syn_doublets).fit(
        X=np.concatenate([pca_proj, syn_doublet_pca_proj], axis=0),
        y=np.repeat([0, 1], [len(pca_proj), n_syn_doublets])
    )
    plt.scatter(pca_proj[:, 0], pca_proj[:, 1])
    plt.scatter(syn_doublet_pca_proj[:, 0], syn_doublet_pca_proj[:, 1])
    plt.show()
    return pd.Series(knn.predict_proba(pca_proj)[:, 1], index=exprs_mat.columns)

# %%
cb_stats['doublet_score'] = doublet_detection(exprs_mat, 2)
cb_stats['cluster'] = (
    (cb_stats.prob_hq > 0.6) &
    (cb_stats.nmarkers > 2) &
    (cb_stats.doublet_score < 0.75)
).map({True: 'hq', False: 'artefact'})
# Out:
# /netscratch/dep_mercier/grp_schneeberger/bin/bin_matt/conda_envs/nb_rpy2/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /netscratch/dep_mercier/grp_schneeberger/bin/bin_matt/conda_envs/nb_rpy2/lib/python3.10/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but PCA was fitted with feature names
#   warnings.warn(

# %%
cb_stats.cluster.value_counts()
# Out:
# cluster
# hq          1394
# artefact     453
# Name: count, dtype: int64

# %%
pp = sns.pairplot(
    hue='cluster',
    data=cb_stats.sample(100),
    x_vars=['nmarkers', 'geno_logprob', 'hmm_score', 'hap_uncertainty', 'mean_hap', 'n_crossovers'],
    y_vars=['nmarkers', 'geno_logprob', 'hmm_score', 'hap_uncertainty', 'mean_hap', 'n_crossovers'],
    hue_order=['hq', 'artefact'],
    kind='kde',
    diag_kind='kde',
    plot_kws={'common_norm': False},
    diag_kws={'common_norm': True}
)

plt.tight_layout()
#plt.savefig(os.path.join(snakemake.output[0], 'cb_stats_pairplot.svg'))
plt.show()

# %%
cb_stats.to_csv(snakemake.output.stats, sep='\t')
