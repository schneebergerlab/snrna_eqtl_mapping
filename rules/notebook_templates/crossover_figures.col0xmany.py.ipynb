# %%
######## snakemake preamble start (automatically inserted, do not edit) ########
import sys; sys.path.extend(['/netscratch/dep_mercier/grp_schneeberger/bin/bin_matt/conda_envs/snakemake8/lib/python3.12/site-packages', '/netscratch/dep_mercier/grp_schneeberger/projects/Athal/Matt_snRNAseq_analysis/diploid_starsolo_pipeline/pipeline/../rules', '/netscratch/dep_mercier/grp_schneeberger/projects/Athal/Matt_snRNAseq_analysis/diploid_starsolo_pipeline/pipeline', '/netscratch/dep_mercier/grp_schneeberger/bin/bin_matt/conda_envs/snakemake8/bin', '/netscratch/dep_mercier/grp_schneeberger/bin/bin_matt/conda_envs/snakemake8/lib/python3.12', '/netscratch/dep_mercier/grp_schneeberger/bin/bin_matt/conda_envs/snakemake8/lib/python3.12/lib-dynload', '/netscratch/dep_mercier/grp_schneeberger/bin/bin_matt/conda_envs/snakemake8/lib/python3.12/site-packages', '/netscratch/dep_mercier/grp_schneeberger/projects/Athal/Matt_snRNAseq_analysis/diploid_starsolo_pipeline/rules/notebook_templates']); import pickle; snakemake = pickle.loads(b'\x80\x04\x95\xf8\r\x00\x00\x00\x00\x00\x00\x8c\x10snakemake.script\x94\x8c\tSnakemake\x94\x93\x94)\x81\x94}\x94(\x8c\x05input\x94\x8c\x0csnakemake.io\x94\x8c\nInputFiles\x94\x93\x94)\x81\x94(\x8c7aligned_data/diploid/col0xmany.col0__vs__db1.sorted.bam\x94\x8c8aligned_data/diploid/col0xmany.col0__vs__kar1.sorted.bam\x94\x8c>aligned_data/diploid/col0xmany.col0__vs__rubezhnoe1.sorted.bam\x94\x8c7aligned_data/diploid/col0xmany.col0__vs__ms0.sorted.bam\x94\x8c8aligned_data/diploid/col0xmany.col0__vs__tsu0.sorted.bam\x94\x8c\x19../annotations/col0_cc.fa\x94\x8c\x15../annotations/db1.fa\x94\x8c\x16../annotations/kar1.fa\x94\x8c\x1c../annotations/rubezhnoe1.fa\x94\x8c\x15../annotations/ms0.fa\x94\x8c\x16../annotations/tsu0.fa\x94\x8c\x1a../annotations/col0_cc.gtf\x94\x8c\x16cb_stats/col0xmany.tsv\x94\x8c2cb_crossovers/col0xmany.col0__vs__db1.co_probs.tsv\x94\x8c3cb_crossovers/col0xmany.col0__vs__kar1.co_probs.tsv\x94\x8c9cb_crossovers/col0xmany.col0__vs__rubezhnoe1.co_probs.tsv\x94\x8c2cb_crossovers/col0xmany.col0__vs__ms0.co_probs.tsv\x94\x8c3cb_crossovers/col0xmany.col0__vs__tsu0.co_probs.tsv\x94\x8c\x19eqtls/col0xmany.eqtls.tsv\x94\x8c7aligned_data/diploid/col0xmany.col0__vs__db1_genecounts\x94\x8c8aligned_data/diploid/col0xmany.col0__vs__kar1_genecounts\x94\x8c>aligned_data/diploid/col0xmany.col0__vs__rubezhnoe1_genecounts\x94\x8c7aligned_data/diploid/col0xmany.col0__vs__ms0_genecounts\x94\x8c8aligned_data/diploid/col0xmany.col0__vs__tsu0_genecounts\x94\x8c3annotation/diploid/vcf/col0xmany.cellsnplite.vcf.gz\x94e}\x94(\x8c\x06_names\x94}\x94(\x8c\x04bams\x94K\x00K\x05\x86\x94\x8c\tref_fasta\x94K\x05N\x86\x94\x8c\x0eparent2_fastas\x94K\x06K\x0b\x86\x94\x8c\x03gtf\x94K\x0bN\x86\x94\x8c\x08cb_stats\x94K\x0cN\x86\x94\x8c\ncrossovers\x94K\rK\x12\x86\x94\x8c\x05eqtls\x94K\x12N\x86\x94\x8c\x05exprs\x94K\x13K\x18\x86\x94\x8c\x03vcf\x94K\x18N\x86\x94u\x8c\x12_allowed_overrides\x94]\x94(\x8c\x05index\x94\x8c\x04sort\x94eh:\x8c\tfunctools\x94\x8c\x07partial\x94\x93\x94h\x06\x8c\x19Namedlist._used_attribute\x94\x93\x94\x85\x94R\x94(h@)}\x94\x8c\x05_name\x94h:sNt\x94bh;h>h@\x85\x94R\x94(h@)}\x94hDh;sNt\x94bh&h\x06\x8c\tNamedlist\x94\x93\x94)\x81\x94(h\nh\x0bh\x0ch\rh\x0ee}\x94(h$}\x94h8]\x94(h:h;eh:h>h@\x85\x94R\x94(h@)}\x94hDh:sNt\x94bh;h>h@\x85\x94R\x94(h@)}\x94hDh;sNt\x94bubh(h\x0fh*hK)\x81\x94(h\x10h\x11h\x12h\x13h\x14e}\x94(h$}\x94h8]\x94(h:h;eh:h>h@\x85\x94R\x94(h@)}\x94hDh:sNt\x94bh;h>h@\x85\x94R\x94(h@)}\x94hDh;sNt\x94bubh,h\x15h.h\x16h0hK)\x81\x94(h\x17h\x18h\x19h\x1ah\x1be}\x94(h$}\x94h8]\x94(h:h;eh:h>h@\x85\x94R\x94(h@)}\x94hDh:sNt\x94bh;h>h@\x85\x94R\x94(h@)}\x94hDh;sNt\x94bubh2h\x1ch4hK)\x81\x94(h\x1dh\x1eh\x1fh h!e}\x94(h$}\x94h8]\x94(h:h;eh:h>h@\x85\x94R\x94(h@)}\x94hDh:sNt\x94bh;h>h@\x85\x94R\x94(h@)}\x94hDh;sNt\x94bubh6h"ub\x8c\x06output\x94h\x06\x8c\x0bOutputFiles\x94\x93\x94)\x81\x94\x8c#figures/crossover_figures_col0xmany\x94a}\x94(h$}\x94\x8c\x07figures\x94K\x00N\x86\x94sh8]\x94(h:h;eh:h>h@\x85\x94R\x94(h@)}\x94hDh:sNt\x94bh;h>h@\x85\x94R\x94(h@)}\x94hDh;sNt\x94bh\x83h\x80ub\x8c\x06params\x94h\x06\x8c\x06Params\x94\x93\x94)\x81\x94}\x94(h$}\x94h8]\x94(h:h;eh:h>h@\x85\x94R\x94(h@)}\x94hDh:sNt\x94bh;h>h@\x85\x94R\x94(h@)}\x94hDh;sNt\x94bub\x8c\twildcards\x94h\x06\x8c\tWildcards\x94\x93\x94)\x81\x94\x8c\tcol0xmany\x94a}\x94(h$}\x94\x8c\x04cond\x94K\x00N\x86\x94sh8]\x94(h:h;eh:h>h@\x85\x94R\x94(h@)}\x94hDh:sNt\x94bh;h>h@\x85\x94R\x94(h@)}\x94hDh;sNt\x94b\x8c\x04cond\x94h\xa1ub\x8c\x07threads\x94K\x05\x8c\tresources\x94h\x06\x8c\tResources\x94\x93\x94)\x81\x94(K\x05K\x01\x8c\x08/scratch\x94e}\x94(h$}\x94(\x8c\x06_cores\x94K\x00N\x86\x94\x8c\x06_nodes\x94K\x01N\x86\x94\x8c\x06tmpdir\x94K\x02N\x86\x94uh8]\x94(h:h;eh:h>h@\x85\x94R\x94(h@)}\x94hDh:sNt\x94bh;h>h@\x85\x94R\x94(h@)}\x94hDh;sNt\x94bh\xb8K\x05h\xbaK\x01h\xbch\xb5ub\x8c\x03log\x94h\x06\x8c\x03Log\x94\x93\x94)\x81\x94}\x94(h$}\x94h8]\x94(h:h;eh:h>h@\x85\x94R\x94(h@)}\x94hDh:sNt\x94bh;h>h@\x85\x94R\x94(h@)}\x94hDh;sNt\x94bub\x8c\x06config\x94}\x94(\x8c\x12reference_genotype\x94\x8c\x04col0\x94\x8c\x08datasets\x94}\x94(\x8c\tcol0xmany\x94}\x94(\x8c\x12reference_genotype\x94\x8c\x04col0\x94\x8c\x12parent2_accessions\x94]\x94(\x8c\x03db1\x94\x8c\x04kar1\x94\x8c\nrubezhnoe1\x94\x8c\x03ms0\x94\x8c\x04tsu0\x94eu\x8c\x08col0xdb1\x94}\x94(\x8c\x12reference_genotype\x94\x8c\x04col0\x94\x8c\x12parent2_accessions\x94]\x94\x8c\x03db1\x94au\x8c\x08db1xcol0\x94}\x94(\x8c\x12reference_genotype\x94\x8c\x03db1\x94\x8c\x12parent2_accessions\x94]\x94\x8c\x04col0\x94auu\x8c\x10genome_fasta_fns\x94}\x94(\x8c\x04col0\x94\x8c\x19../annotations/col0_cc.fa\x94\x8c\x03db1\x94\x8c\x15../annotations/db1.fa\x94\x8c\x04kar1\x94\x8c\x16../annotations/kar1.fa\x94\x8c\nrubezhnoe1\x94\x8c\x1c../annotations/rubezhnoe1.fa\x94\x8c\x03ms0\x94\x8c\x15../annotations/ms0.fa\x94\x8c\x04tsu0\x94\x8c\x16../annotations/tsu0.fa\x94u\x8c\x07gtf_fns\x94}\x94(\x8c\x04col0\x94\x8c\x1a../annotations/col0_cc.gtf\x94\x8c\x03db1\x94\x8c\x16../annotations/db1.gtf\x94u\x8c\x11barcode_whitelist\x94\x8c#../annotations/3M-february-2018.txt\x94\x8c\x1aorganellar_genome_fasta_fn\x94\x8c\x1c../annotations/organellar.fa\x94\x8c\x11organellar_gtf_fn\x94\x8c\x1d../annotations/organellar.gtf\x94u\x8c\x04rule\x94\x8c\x11crossover_figures\x94\x8c\x0fbench_iteration\x94N\x8c\tscriptdir\x94\x8c\x81/netscratch/dep_mercier/grp_schneeberger/projects/Athal/Matt_snRNAseq_analysis/diploid_starsolo_pipeline/rules/notebook_templates\x94ub.'); from snakemake.logging import logger; logger.printshellcmds = True; import os; os.chdir(r'/netscratch/dep_mercier/grp_schneeberger/projects/Athal/Matt_snRNAseq_analysis/diploid_starsolo_pipeline/pipeline');
######## snakemake preamble end #########

# %%
import sys
import os
import re
from glob import glob
import random
import itertools as it
import warnings
from collections import Counter, defaultdict
from functools import reduce

import numpy as np
import pandas as pd
from scipy import stats, sparse
from statsmodels.stats.multitest import fdrcorrection
import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator
from matplotlib.colors import ListedColormap, Normalize, LinearSegmentedColormap
import seaborn as sns


sys.path.extend([os.path.abspath('../scripts/')])
from singlecell_snptools.io import parse_gtf, get_chrom_sizes_bam
from singlecell_snptools.markers import parallel_read_bams
from singlecell_snptools.plot import chrom_axes_boilerplate


## Default plotting params

# %matplotlib inline
sns.set(font='Arial')
plt.rcParams['svg.fonttype'] = 'none'
style = sns.axes_style('white')
style.update(sns.axes_style('ticks'))
style['xtick.major.size'] = 1
style['ytick.major.size'] = 1
sns.set(font_scale=1, style=style)
pal = sns.color_palette(['#0072b2', '#d55e00', '#009e73', '#f0e442', '#cc79a7', '#56b4e9', '#e69f00'])
cmap = ListedColormap(pal.as_hex())
sns.set_palette(pal)
sns.palplot(pal)
plt.show()

# %%
if not os.path.exists(snakemake.output[0]):
    os.mkdir(snakemake.output[0])

# %%
cb_stats = pd.read_csv(
    snakemake.input.cb_stats,
    sep='\t'
)
cb_genotypes = cb_stats.set_index('cb').geno.to_dict()

# %%
cb_stats.query('cluster == "hq"').n_crossovers.median()
# Out:
# 4.891327610348453

# %%
def bootstrap_conf_interval(arr, percentiles=[2.5, 50, 97.5], nboot=10000, estimator=np.median):
    boots = []
    for _ in range(nboot):
        boots.append(estimator(np.random.choice(arr, size=len(arr), replace=True)))
    return np.percentile(boots, percentiles)

nmarkers = 10 ** cb_stats.query('cluster == "hq"').nmarkers.values
bootstrap_conf_interval(nmarkers)
# Out:
# array([427. , 458. , 494.5])

# %%
fig, ax = plt.subplots()
logbins = np.logspace(np.log10(50), np.log10(5000), 50)
ax.hist(x=nmarkers, bins=logbins)
ax.set_xscale('log')
ax.set_xlabel('Markers per nucleus')
ax.set_ylabel('Nuclei (count)')
plt.savefig(os.path.join(snakemake.output[0], 'nmarkers_hist.svg'))
plt.show()

# %%
ax = sns.violinplot(
    x='geno',
    y='n_crossovers',
    data=cb_stats.query('cluster == "hq"'),
    order=['db1', 'kar1', 'ms0', 'rubezhnoe1', 'tsu0'],
    cut=0
)
for geno, c in zip(['db1', 'kar1', 'ms0', 'rubezhnoe1', 'tsu0'], pal):
    m = np.median(cb_stats.query('cluster == "hq" & geno == @geno').n_crossovers)
    ax.axhline(m, color=c, ls='-', zorder=0, lw=2)
ax.set_ylim(0, 13)
ax.yaxis.set_minor_locator(MultipleLocator(1))
ax.set_xlabel('Genotype')
ax.set_xticklabels(['Db-1', 'Kar-1', 'Ms-0', 'Rubezhnoe-1', 'Tsu-0'])
ax.set_ylabel('Estimated number of\ncrossovers per nucleus')
plt.savefig(os.path.join(snakemake.output[0], 'ncrossovers.svg'))
plt.show()

# %%
cb_stats.query('cluster == "hq"').groupby('geno').n_crossovers.mean()
# Out:
# geno
# db1           5.312320
# kar1          4.969253
# ms0           4.887638
# rubezhnoe1    4.512794
# tsu0          4.574316
# Name: n_crossovers, dtype: float64

# %%
pp = sns.pairplot(
    hue='cluster',
    data=cb_stats.sample(1000),
    x_vars=['nmarkers', 'geno_logprob', 'hmm_score', 'hap_uncertainty', 'mean_hap', 'prob_hq', 'n_crossovers'],
    y_vars=['nmarkers', 'geno_logprob', 'hmm_score', 'hap_uncertainty', 'mean_hap', 'prob_hq', 'n_crossovers'],
    kind='kde',
    diag_kind='kde',
    plot_kws={'common_norm': False},
    diag_kws={'common_norm': True}
)

plt.tight_layout()
#plt.savefig(os.path.join(snakemake.output[0], 'cb_stats_pairplot.svg'))
plt.show()

# %%
hap_probs = pd.concat((
    pd.read_csv(fn, sep='\t', header=[0, 1], index_col=[0, 1])
    for fn in snakemake.input.crossovers
), axis=0)
hap_probs.index = hap_probs.index.droplevel('fn_idx')

# %%
chrom_sizes = get_chrom_sizes_bam(snakemake.input.bams[0])

# %%
def calculate_cm_per_mb(hap_probs, nboots=100, bin_size=25_000, cm_bin_size=1_000_000, min_prob=0.01):

    nf = 1_000_000 // bin_size
    ws = cm_bin_size // bin_size
    mw = ws // 2
    
    boots = {}
    for chrom, chrom_hap_probs in hap_probs.groupby(level=0, axis=1, group_keys=False):
        chrom_hap_probs.columns = chrom_hap_probs.columns.droplevel(0)
        chrom_co_probs = (chrom_hap_probs.diff(1, axis=1)
                                         .abs()
                                         .fillna(0))
        #for i in range(int(ws)):
        #    chrom_co_probs.iloc[:, i] = chrom_co_probs.iloc[:, int(ws)]
        #    chrom_co_probs.iloc[:, -i] = chrom_co_probs.iloc[:, -int(ws)]
        chrom_co_probs.mask(chrom_co_probs < min_prob, other=0, inplace=True)
        # equivalent to rolling sum accounting for edge effects
        chrom_co_probs = chrom_co_probs.rolling(ws, center=True, min_periods=mw, axis=1).mean() * nf
        chrom_boots = []
        for _ in range(nboots):
            cm_samp = chrom_co_probs.sample(len(chrom_co_probs), replace=True).mean(axis=0)
            chrom_boots.append(cm_samp * 100)
        boots[chrom] = pd.concat(chrom_boots, axis=1)
    return boots

# %%
for geno, c in zip(snakemake.config['datasets'][snakemake.wildcards.cond]['parent2_accessions'], pal):
    idx = cb_stats.query('cluster == "hq" & geno == @geno').cb
    n = len(idx)
    hp = hap_probs.loc[idx]
    cm = calculate_cm_per_mb(hp, nboots=100)
    tot_co = hp.groupby(level=0, axis=1).diff(1, axis=1).abs().sum().sum()
    fig, axes = chrom_axes_boilerplate(chrom_sizes, figsize=(12, 3))
    axes = axes.flatten()
    for chrom, ax in zip(chrom_sizes, axes):
        ax.step(cm[chrom].index.astype(int), cm[chrom].mean(1).values, color=c)
        ax.fill_between(x=cm[chrom].index.astype(int), y1=np.percentile(cm[chrom].values, 2.5, axis=1), y2=np.percentile(cm[chrom].values, 97.5, axis=1), alpha=0.25, color=c)
    axes[0].set_ylabel('cM / Mb')
    axes[0].set_ylim(-1, 12.5)
    fig.suptitle(f'Col-0 x {geno} crossover landscape (n = {n} nuclei, {tot_co:.0f} COs)')
    plt.tight_layout()
    plt.savefig(os.path.join(snakemake.output[0], f'{geno}_co_landscape.svg'))
    plt.show()

# %%
co_markers, percent_contamination, chrom_sizes = parallel_read_bams(
    [fn.replace('sorted', 'filt') for fn in snakemake.input.bams],
    25_000,
    whitelist=set(cb_stats.cb.values),
    max_bin_count=20
)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[240], line 1
# ----> 1 co_markers, percent_contamination, chrom_sizes = parallel_read_bams(
#       2     [fn.replace('sorted', 'filt') for fn in snakemake.input.bams],
#       3     25_000,
#       4     whitelist=set(cb_stats.cb.values),
#       5     max_bin_count=20
#       6 )
#
# File /netscratch/dep_mercier/grp_schneeberger/projects/Athal/Matt_snRNAseq_analysis/diploid_starsolo_pipeline/scripts/singlecell_snptools/markers.py:116, in parallel_read_bams(bam_fns, bin_size, processes, whitelist_fn, whitelist, max_bin_count, bg_window_size)
#     114     whitelist = read_cb_whitelist(whitelist_fn)
#     115 with Parallel(n_jobs=min(processes, len(bam_fns)), backend='loky', verbose=True) as pool:
# --> 116     res = pool(
# ...

# %%
gene_locs = pd.DataFrame.from_dict(
    parse_gene_positions(snakemake.config['gtf_fns']['col0']),
    columns=['chrom', 'pos'],
    orient='index'
)
gene_locs['pos_bin'] = (gene_locs.pos // 25_000) * 25_000
gene_density = gene_locs.groupby(['chrom', 'pos_bin']).size() / 25

# %%
MAX_HEIGHT = 1

centromere_pos = {
    'Chr1': [(14377135, 17931424)],
    'Chr2': [(4073667, 6832398)],
    'Chr3': [(12679318, 15825034)],
    'Chr4': [(2944938, 7338649)],
    'Chr5': [(11947852, 15173109)],
}

fig, axes = chrom_axes_boilerplate(chrom_sizes, nrows=2, figsize=(12, 5), row_ratios=(0.3, 0.7), span_features=centromere_pos)

for chrom, ax in zip(chrom_sizes, axes[0]):
    x = np.arange(0, chrom_sizes[chrom], 25_000)
    ax.step(x, np.minimum(gene_density[chrom].reindex(x).fillna(0).values, 1))
axes[0, 0].set_ylabel('Annotated\ngenes per kb')

for chrom, ax in zip(chrom_sizes, axes[1]):
    obs = np.log10(np.mean([m[chrom].astype(int) for m in co_markers.values()], axis=0) + 1)
    x = np.arange(0, chrom_sizes[chrom], 25_000)
    ax.step(x, obs[:, 0])
    ax.step(x, np.negative(obs[:, 1]))
axes[1, 0].set_ylabel('Normalised marker density')
plt.savefig(os.path.join(snakemake.output[0], f'marker_density.svg'))
plt.show()

# %%
def ref_alt_rugplot(co_markers, chrom_size, bin_size, ax=None, max_height=20):
    pos = np.arange(len(co_markers)) * bin_size
    rwgt = co_markers[:, 0].astype(np.int16)
    rwgt[rwgt > max_height] = max_height
    awgt = co_markers[:, 1].astype(np.int16)
    awgt[awgt > max_height] = max_height
    if ax is None:
        fig, ax = plt.subplots(figsize=(8, 5))
    ax.vlines(pos, np.repeat(0, len(pos)), rwgt, color=pal[0], zorder=0)
    ax.vlines(pos, np.repeat(0, len(pos)), np.negative(awgt), color=pal[1], zorder=0)
    ax.plot([0, chrom_size], [0, 0], ls='-', color='#252525')
    return ax

# %%
MAX_HEIGHT = 20
cmap = LinearSegmentedColormap.from_list('', list(pal)[:2])

hq_examples =  cb_stats.query('cluster == "hq" & prob_hq > 0.9').sample(10).cb.values

for (fn_idx, cb), cb_co_markers in co_markers.items():
    if cb not in hq_examples:
        continue
    print(cb)
    fig, axes = plt.subplots(figsize=(20, 4), ncols=len(chrom_sizes), width_ratios=list(chrom_sizes.values()), sharey=True)
    for chrom, ax in zip(chrom_sizes, axes):
        chrom_co_markers = cb_co_markers[chrom]
        ref_alt_rugplot(chrom_co_markers, chrom_sizes[chrom], 25_000, ax=ax, max_height=MAX_HEIGHT)
        c = hap_probs.loc[cb, chrom]
        co = np.abs(np.diff(c.values)).sum()
        ax.annotate(text=f'{co.sum():.2f} COs', xy=(0.05, 0.1), xycoords='axes fraction')
        x = np.insert(c.index.values.astype(int), len(c), chrom_sizes[chrom])
        y = np.array([-MAX_HEIGHT - 1, MAX_HEIGHT + 1])
        ax.pcolormesh(x, y, c.values.reshape(1, -1), cmap=cmap, norm=Normalize(0, 1), alpha=0.5, zorder=-2, rasterized=True)
        ax.set_xlim(-1e4, chrom_sizes[chrom] + 1e4)
        ax.plot(c.index.values.astype(int) + 12_500, np.negative(c.values - 0.5) * (MAX_HEIGHT * 2 - 1), color='#eeeeee', lw=2, zorder=-1)
        ax.set_xticks(np.arange(0, chrom_sizes[chrom], 1e7))
        ax.set_yticks([-20, -10, 0, 10, 20])
        ax.set_yticklabels([20, 10, 0, 10, 20])
        ax.set_xticklabels([int(i // 1e6) for i in np.arange(0, chrom_sizes[chrom], 1e7)])
        if chrom == '1':
            ax.set_ylabel('Marker coverage')
        ax.set_xlabel(f'Chromosome {chrom} (Mb)')
    plt.tight_layout()
    plt.savefig(os.path.join(snakemake.output[0], f'marker_rugplot_{cb}.svg'))
    plt.show()
# Out:
# TTCCAATCAGTACTAC
# TCCGATCGTCTGGTTA
# GTCATGATCGACGCTG
# TCCACGTAGTGCAACG
# GTAATCGAGTCAATCC
# ATGAAAGTCGGCCAAC
# TAACGACGTAGCTGAG
# ATCCATTGTGGATACG
# CTGTGAACAAACGAGC
# AGACAAAAGGAACTAT
