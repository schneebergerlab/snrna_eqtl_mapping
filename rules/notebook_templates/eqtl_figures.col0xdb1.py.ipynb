# %%
######## snakemake preamble start (automatically inserted, do not edit) ########
import sys; sys.path.extend(['/netscratch/dep_mercier/grp_schneeberger/bin/bin_matt/conda_envs/snakemake8/lib/python3.12/site-packages', '/netscratch/dep_mercier/grp_schneeberger/projects/Athal/Matt_snRNAseq_analysis/diploid_starsolo_pipeline/pipeline/../rules', '/netscratch/dep_mercier/grp_schneeberger/projects/Athal/Matt_snRNAseq_analysis/diploid_starsolo_pipeline/pipeline', '/netscratch/dep_mercier/grp_schneeberger/bin/bin_matt/conda_envs/snakemake8/bin', '/netscratch/dep_mercier/grp_schneeberger/bin/bin_matt/conda_envs/snakemake8/lib/python3.12', '/netscratch/dep_mercier/grp_schneeberger/bin/bin_matt/conda_envs/snakemake8/lib/python3.12/lib-dynload', '/netscratch/dep_mercier/grp_schneeberger/bin/bin_matt/conda_envs/snakemake8/lib/python3.12/site-packages', '/netscratch/dep_mercier/grp_schneeberger/projects/Athal/Matt_snRNAseq_analysis/diploid_starsolo_pipeline/rules/notebook_templates']); import pickle; snakemake = pickle.loads(b"\x80\x04\x95V\n\x00\x00\x00\x00\x00\x00\x8c\x10snakemake.script\x94\x8c\tSnakemake\x94\x93\x94)\x81\x94}\x94(\x8c\x05input\x94\x8c\x0csnakemake.io\x94\x8c\nInputFiles\x94\x93\x94)\x81\x94(\x8c6aligned_data/diploid/col0xdb1.col0__vs__db1.sorted.bam\x94\x8c\x19../annotations/col0_cc.fa\x94\x8c\x15../annotations/db1.fa\x94\x8c\x1a../annotations/col0_cc.gtf\x94\x8c\x15cb_stats/col0xdb1.tsv\x94\x8c1cb_crossovers/col0xdb1.col0__vs__db1.co_probs.tsv\x94\x8c\x18eqtls/col0xdb1.eqtls.tsv\x94\x8c6aligned_data/diploid/col0xdb1.col0__vs__db1_genecounts\x94e}\x94(\x8c\x06_names\x94}\x94(\x8c\x04bams\x94K\x00K\x01\x86\x94\x8c\tref_fasta\x94K\x01N\x86\x94\x8c\x0eparent2_fastas\x94K\x02K\x03\x86\x94\x8c\x03gtf\x94K\x03N\x86\x94\x8c\x08cb_stats\x94K\x04N\x86\x94\x8c\ncrossovers\x94K\x05K\x06\x86\x94\x8c\x05eqtls\x94K\x06N\x86\x94\x8c\x05exprs\x94K\x07K\x08\x86\x94u\x8c\x12_allowed_overrides\x94]\x94(\x8c\x05index\x94\x8c\x04sort\x94eh'\x8c\tfunctools\x94\x8c\x07partial\x94\x93\x94h\x06\x8c\x19Namedlist._used_attribute\x94\x93\x94\x85\x94R\x94(h-)}\x94\x8c\x05_name\x94h'sNt\x94bh(h+h-\x85\x94R\x94(h-)}\x94h1h(sNt\x94bh\x15h\x06\x8c\tNamedlist\x94\x93\x94)\x81\x94h\na}\x94(h\x13}\x94h%]\x94(h'h(eh'h+h-\x85\x94R\x94(h-)}\x94h1h'sNt\x94bh(h+h-\x85\x94R\x94(h-)}\x94h1h(sNt\x94bubh\x17h\x0bh\x19h8)\x81\x94h\x0ca}\x94(h\x13}\x94h%]\x94(h'h(eh'h+h-\x85\x94R\x94(h-)}\x94h1h'sNt\x94bh(h+h-\x85\x94R\x94(h-)}\x94h1h(sNt\x94bubh\x1bh\rh\x1dh\x0eh\x1fh8)\x81\x94h\x0fa}\x94(h\x13}\x94h%]\x94(h'h(eh'h+h-\x85\x94R\x94(h-)}\x94h1h'sNt\x94bh(h+h-\x85\x94R\x94(h-)}\x94h1h(sNt\x94bubh!h\x10h#h8)\x81\x94h\x11a}\x94(h\x13}\x94h%]\x94(h'h(eh'h+h-\x85\x94R\x94(h-)}\x94h1h'sNt\x94bh(h+h-\x85\x94R\x94(h-)}\x94h1h(sNt\x94bubub\x8c\x06output\x94h\x06\x8c\x0bOutputFiles\x94\x93\x94)\x81\x94\x8c\x1dfigures/eqtl_figures_col0xdb1\x94a}\x94(h\x13}\x94\x8c\x07figures\x94K\x00N\x86\x94sh%]\x94(h'h(eh'h+h-\x85\x94R\x94(h-)}\x94h1h'sNt\x94bh(h+h-\x85\x94R\x94(h-)}\x94h1h(sNt\x94bhphmub\x8c\x06params\x94h\x06\x8c\x06Params\x94\x93\x94)\x81\x94}\x94(h\x13}\x94h%]\x94(h'h(eh'h+h-\x85\x94R\x94(h-)}\x94h1h'sNt\x94bh(h+h-\x85\x94R\x94(h-)}\x94h1h(sNt\x94bub\x8c\twildcards\x94h\x06\x8c\tWildcards\x94\x93\x94)\x81\x94\x8c\x08col0xdb1\x94a}\x94(h\x13}\x94\x8c\x04cond\x94K\x00N\x86\x94sh%]\x94(h'h(eh'h+h-\x85\x94R\x94(h-)}\x94h1h'sNt\x94bh(h+h-\x85\x94R\x94(h-)}\x94h1h(sNt\x94b\x8c\x04cond\x94h\x8eub\x8c\x07threads\x94K\x01\x8c\tresources\x94h\x06\x8c\tResources\x94\x93\x94)\x81\x94(K\x01K\x01\x8c\x08/scratch\x94e}\x94(h\x13}\x94(\x8c\x06_cores\x94K\x00N\x86\x94\x8c\x06_nodes\x94K\x01N\x86\x94\x8c\x06tmpdir\x94K\x02N\x86\x94uh%]\x94(h'h(eh'h+h-\x85\x94R\x94(h-)}\x94h1h'sNt\x94bh(h+h-\x85\x94R\x94(h-)}\x94h1h(sNt\x94bh\xa5K\x01h\xa7K\x01h\xa9h\xa2ub\x8c\x03log\x94h\x06\x8c\x03Log\x94\x93\x94)\x81\x94}\x94(h\x13}\x94h%]\x94(h'h(eh'h+h-\x85\x94R\x94(h-)}\x94h1h'sNt\x94bh(h+h-\x85\x94R\x94(h-)}\x94h1h(sNt\x94bub\x8c\x06config\x94}\x94(\x8c\x12reference_genotype\x94\x8c\x04col0\x94\x8c\x08datasets\x94}\x94(\x8c\tcol0xmany\x94}\x94(\x8c\x12reference_genotype\x94\x8c\x04col0\x94\x8c\x12parent2_accessions\x94]\x94(\x8c\x03db1\x94\x8c\x04kar1\x94\x8c\nrubezhnoe1\x94\x8c\x03ms0\x94\x8c\x04tsu0\x94eu\x8c\x08col0xdb1\x94}\x94(\x8c\x12reference_genotype\x94\x8c\x04col0\x94\x8c\x12parent2_accessions\x94]\x94\x8c\x03db1\x94au\x8c\x08db1xcol0\x94}\x94(\x8c\x12reference_genotype\x94\x8c\x03db1\x94\x8c\x12parent2_accessions\x94]\x94\x8c\x04col0\x94auu\x8c\x10genome_fasta_fns\x94}\x94(\x8c\x04col0\x94\x8c\x19../annotations/col0_cc.fa\x94\x8c\x03db1\x94\x8c\x15../annotations/db1.fa\x94\x8c\x04kar1\x94\x8c\x16../annotations/kar1.fa\x94\x8c\nrubezhnoe1\x94\x8c\x1c../annotations/rubezhnoe1.fa\x94\x8c\x03ms0\x94\x8c\x15../annotations/ms0.fa\x94\x8c\x04tsu0\x94\x8c\x16../annotations/tsu0.fa\x94u\x8c\x07gtf_fns\x94}\x94(\x8c\x04col0\x94\x8c\x1a../annotations/col0_cc.gtf\x94\x8c\x03db1\x94\x8c\x16../annotations/db1.gtf\x94u\x8c\x11barcode_whitelist\x94\x8c#../annotations/3M-february-2018.txt\x94\x8c\x1aorganellar_genome_fasta_fn\x94\x8c\x1c../annotations/organellar.fa\x94\x8c\x11organellar_gtf_fn\x94\x8c\x1d../annotations/organellar.gtf\x94u\x8c\x04rule\x94\x8c\x0ceqtl_figures\x94\x8c\x0fbench_iteration\x94N\x8c\tscriptdir\x94\x8c\x81/netscratch/dep_mercier/grp_schneeberger/projects/Athal/Matt_snRNAseq_analysis/diploid_starsolo_pipeline/rules/notebook_templates\x94ub."); from snakemake.logging import logger; logger.printshellcmds = True; import os; os.chdir(r'/netscratch/dep_mercier/grp_schneeberger/projects/Athal/Matt_snRNAseq_analysis/diploid_starsolo_pipeline/pipeline');
######## snakemake preamble end #########

# %%
import sys
import os
import re
from copy import copy
from io import StringIO
from glob import glob
import random
import itertools as it
import warnings
from collections import Counter, defaultdict
from contextlib import contextmanager

import numpy as np
import pandas as pd
from scipy import stats
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap, Normalize
from matplotlib.cm import ScalarMappable
from matplotlib.patches import Rectangle
from matplotlib_venn import venn3, venn2
from sklearn.mixture import GaussianMixture
from sklearn.decomposition import PCA
import seaborn as sns

import pysam

sys.path.extend([os.path.abspath('../scripts/')])

from singlecell_snptools.io import parse_gene_positions
from singlecell_snptools.eqtl import call_lod_peaks
from singlecell_snptools.exprs import read_mmformat, lognormalise_exprs
from singlecell_snptools.plot import chrom_axes_boilerplate, create_eqtl_plotter, create_haplotype_expression_plotter
from singlecell_snptools.distortion import segregation_distortion

## Default plotting params

# %matplotlib inline
sns.set(font='Arial')
plt.rcParams['svg.fonttype'] = 'none'
style = sns.axes_style('white')
style.update(sns.axes_style('ticks'))
style['xtick.major.size'] = 1
style['ytick.major.size'] = 1
sns.set(font_scale=1, style=style)
pal = sns.color_palette(['#0072b2', '#d55e00', '#009e73', '#f0e442', '#cc79a7', '#56b4e9', '#e69f00'])
cmap = ListedColormap(pal.as_hex())
sns.set_palette(pal)
sns.palplot(pal)
plt.show()

# %%
if not os.path.exists(snakemake.output[0]):
    os.mkdir(snakemake.output[0])

# %%
snakemake.input.eqtls = 'eqtls/col0xdb1.all.eqtls.tsv'

# %%
cb_stats = pd.read_csv(
    snakemake.input.cb_stats,
    header=0,
    index_col=0,
    sep='\t',
).query('cluster == "hq"')
cb_stats['celltype'] = (pd.read_csv(snakemake.input.eqtls.replace('all.eqtls.tsv', 'all.covars.tsv'), sep='\t', index_col=0)['cluster1'] > 0.5).map({False: 'Vegetative', True: 'Sperm'})
cb_whitelist = sorted(cb_stats.index.tolist())

exprs_mat, _ = lognormalise_exprs(read_mmformat(
    snakemake.input.exprs,
    cb_whitelist
))

hap_probs = pd.concat((
    pd.read_csv(fn, sep='\t', header=[0, 1], index_col=[0, 1])
    for fn in snakemake.input.crossovers
), axis=0)
hap_probs.index = hap_probs.index.droplevel('fn_idx')
hap_probs.columns = hap_probs.columns.set_levels(hap_probs.columns.levels[1].astype(int), level=1)

eqtl_res = pd.read_csv(snakemake.input.eqtls, sep='\t', dtype={'chrom': str})
chrom_sizes = eqtl_res.groupby('chrom').pos.max().to_dict()
sig_eqtl = call_lod_peaks(eqtl_res, snakemake.input.gtf)
sig_eqtl_celltype = call_lod_peaks(eqtl_res, snakemake.input.gtf, cell_type_specific=True)
sig_eqtl_celltype['cluster'] = sig_eqtl_celltype.eval('(hap2_x_cluster1_pval < 0.05) + (hap2_x_cluster2_pval < 0.05) * 2').map({0: 'Neither', 1: 'Sperm', 2: 'Vegetative', 3: 'Both'})
eqtl_res.head()
# Out:
#   chrom  pos    gene_id  lod_score      lrt_pval     hap2_pval  hap2_coef  \
# 0  Chr1    0  AT1G01020    0.08102  1.000000e+00  1.000000e+00   0.004813
# 1  Chr1    0  AT1G01310    0.88060  1.000000e+00  1.000000e+00   0.022890
# 2  Chr1    0  AT1G01320   57.65000  6.020000e-55  6.408000e-55   0.440500
# 3  Chr1    0  AT1G01340    1.75500  1.000000e+00  1.000000e+00  -0.061750
# 4  Chr1    0  AT1G01460    0.08060  1.000000e+00  1.000000e+00  -0.005872
#
#    cluster_lod_score  cluster_lrt_pval  hap2_x_cluster1_pval  \
# 0            0.08102      1.000000e+00          1.000000e+00
# 1            0.88060      1.000000e+00          1.000000e+00
# 2           57.65000      6.020000e-55          6.135000e-63
# 3            1.75500      1.000000e+00          1.000000e+00
# 4            0.08060      1.000000e+00          1.000000e+00
#
#    hap2_x_cluster2_pval  hap2_x_cluster1_coef  hap2_x_cluster2_coef
# 0               1.00000              0.005559              0.000778
# ...

# %%
pca = PCA(n_components=10, svd_solver='arpack')
pca_proj = pca.fit_transform(exprs_mat.T)
pca_proj = pd.DataFrame(pca_proj, index=exprs_mat.columns, columns=[f'PC{i}' for i in range(1, 11)])

cluster_labels = pd.Series(GaussianMixture(covariance_type='spherical', n_components=2, random_state=101).fit(pca_proj).predict(pca_proj), index=pca_proj.index)
cb_stats['celltype_cluster'] = cluster_labels

# %%
fig, axes = chrom_axes_boilerplate(chrom_sizes, figsize=(10, 10), nrows='nchroms')
axes = axes[::-1]
chroms = list(chrom_sizes)

CIS_RANGE = 2e6
TRANS_RANGE = np.array([[25e6, 27e6], [14e6, 20e6]])
TRANS_RANGE_COLORS = [pal[2], pal[3]]

for i, j in it.product(range(len(chrom_sizes)), repeat=2):
    c_i, c_j = chroms[i], chroms[j]
    d = sig_eqtl.query('chrom_gene == @c_i & chrom_eqtl == @c_j')
    sns.scatterplot(
        x=d.pos_eqtl,
        y=d.pos_gene,
        hue=d.is_cis,
        size=d.lod_score,
        sizes=(5, 100),
        size_norm=(3, 50),
        hue_order=[False, True],
        palette=pal[:2],
        ax=axes[i][j],
        zorder=3
    )
    axes[i][j].errorbar(
        x=d.pos_eqtl,
        y=d.pos_gene,
        xerr=[d.pos_eqtl - d.start_eqtl,
              d.end_eqtl - d.pos_eqtl],
        color='#777777',
        zorder=2,
        linestyle='None',
        marker='None',
        alpha=0.75
    )
    try:
        axes[i][j].legend_.remove()
    except:
        pass

    if i == j:
        axes[i][j].fill_between(
            x=[0, CIS_RANGE, chrom_sizes[c_j] - CIS_RANGE, chrom_sizes[c_j]],
            y1=[0, 0, chrom_sizes[c_i] - CIS_RANGE * 2, chrom_sizes[c_i] - CIS_RANGE],
            y2=[CIS_RANGE, CIS_RANGE * 2, chrom_sizes[c_i], chrom_sizes[c_i]],
            color=pal[1],
            alpha=0.1,
            zorder=1,
            edgecolor='none',
        )
    
    axes[i][j].set_ylim(-500_000, chrom_sizes[c_i] + 500_000)
    axes[i][j].set_xlim(-500_000, chrom_sizes[c_j] + 500_000)

    if c_j == 'Chr1':
        for TR, c in zip(TRANS_RANGE, TRANS_RANGE_COLORS):
            if c_i != c_j:
                axes[i][j].axvspan(*TR, color=c, alpha=0.2, zorder=1)
            else:
                axes[i][j].fill_between(
                    x=TR,
                    y1=[0, 0],
                    y2=TR - CIS_RANGE,
                    color=c,
                    alpha=0.2,
                    zorder=1,
                    edgecolor='none',
                )
                axes[i][j].fill_between(
                    x=TR,
                    y1=TR + CIS_RANGE,
                    y2=[chrom_sizes[c_i], chrom_sizes[c_i]],
                    color=c,
                    alpha=0.2,
                    zorder=1,
                    edgecolor='none',
                )

for ax, chrom in zip(axes[0], chroms):
    ax.set_xticks(np.arange(0, chrom_sizes[chrom], 1e7))
    ax.set_xticklabels([int(i // 1e6) for i in np.arange(0, chrom_sizes[chrom], 1e7)])
    ax.set_xlabel(f'{chrom} (Mb)')

for ax, chrom in zip(axes[:, 0], chroms):
    ax.set_yticks(np.arange(0, chrom_sizes[chrom], 1e7))
    ax.set_yticklabels([int(i // 1e6) for i in np.arange(0, chrom_sizes[chrom], 1e7)])
    ax.set_ylabel(f'{chrom} (Mb)')

fig.supxlabel('eQTL position')
fig.supylabel('Gene position')

plt.tight_layout(h_pad=0.1, w_pad=0.1)

plt.savefig(os.path.join(snakemake.output[0], 'eqtl_scatterplot.svg'))
plt.show()

# %%
fig, axes = chrom_axes_boilerplate(chrom_sizes, figsize=(10, 10), nrows='nchroms')
axes = axes[::-1]
chroms = list(chrom_sizes)

CIS_RANGE = 2e6
TRANS_RANGE = np.array([[25e6, 27e6], [14e6, 22e6]])
TRANS_RANGE_COLORS = [pal[2], pal[3]]

for i, j in it.product(range(len(chrom_sizes)), repeat=2):
    c_i, c_j = chroms[i], chroms[j]
    d = sig_eqtl_celltype.query('chrom_gene == @c_i & chrom_eqtl == @c_j')
    sns.scatterplot(
        x=d.pos_eqtl,
        y=d.pos_gene,
        hue=d.cluster,
        size=d.lod_score,
        sizes=(5, 100),
        size_norm=(3, 50),
        hue_order=['Sperm', 'Vegetative', 'Both', 'Neither'],
        palette=pal[:4],
        ax=axes[i][j],
        zorder=3
    )
    axes[i][j].errorbar(
        x=d.pos_eqtl,
        y=d.pos_gene,
        xerr=[d.pos_eqtl - d.start_eqtl,
              d.end_eqtl - d.pos_eqtl],
        color='#777777',
        zorder=2,
        linestyle='None',
        marker='None',
        alpha=0.75
    )
    try:
        axes[i][j].legend_.remove()
    except:
        pass

    if i == j:
        axes[i][j].fill_between(
            x=[0, CIS_RANGE, chrom_sizes[c_j] - CIS_RANGE, chrom_sizes[c_j]],
            y1=[0, 0, chrom_sizes[c_i] - CIS_RANGE * 2, chrom_sizes[c_i] - CIS_RANGE],
            y2=[CIS_RANGE, CIS_RANGE * 2, chrom_sizes[c_i], chrom_sizes[c_i]],
            color=pal[1],
            alpha=0.1,
            zorder=1,
            edgecolor='none',
        )
    
    axes[i][j].set_ylim(-500_000, chrom_sizes[c_i] + 500_000)
    axes[i][j].set_xlim(-500_000, chrom_sizes[c_j] + 500_000)

    if c_j == 'Chr1':
        for TR, c in zip(TRANS_RANGE, TRANS_RANGE_COLORS):
            if c_i != c_j:
                axes[i][j].axvspan(*TR, color=c, alpha=0.2, zorder=1)
            else:
                axes[i][j].fill_between(
                    x=TR,
                    y1=[0, 0],
                    y2=TR - CIS_RANGE,
                    color=c,
                    alpha=0.2,
                    zorder=1,
                    edgecolor='none',
                )
                axes[i][j].fill_between(
                    x=TR,
                    y1=TR + CIS_RANGE,
                    y2=[chrom_sizes[c_i], chrom_sizes[c_i]],
                    color=c,
                    alpha=0.2,
                    zorder=1,
                    edgecolor='none',
                )

for ax, chrom in zip(axes[0], chroms):
    ax.set_xticks(np.arange(0, chrom_sizes[chrom], 1e7))
    ax.set_xticklabels([int(i // 1e6) for i in np.arange(0, chrom_sizes[chrom], 1e7)])
    ax.set_xlabel(f'{chrom} (Mb)')

for ax, chrom in zip(axes[:, 0], chroms):
    ax.set_yticks(np.arange(0, chrom_sizes[chrom], 1e7))
    ax.set_yticklabels([int(i // 1e6) for i in np.arange(0, chrom_sizes[chrom], 1e7)])
    ax.set_ylabel(f'{chrom} (Mb)')

fig.supxlabel('eQTL position')
fig.supylabel('Gene position')

plt.tight_layout(h_pad=0.1, w_pad=0.1)

plt.savefig(os.path.join(snakemake.output[0], 'eqtl_scatterplot_celltype.svg'))
plt.show()

# %%
def dist_to_eqtl(eqtl_df, bin_size=25000):
    is_right_of_eqtl = eqtl_df.pos_gene > eqtl_df.pos_eqtl
    is_exact = (eqtl_df.pos_eqtl <= eqtl_df.pos_gene) & (eqtl_df.pos_gene < (eqtl_df.pos_eqtl + bin_size))
    dist = eqtl_df.pos_eqtl - eqtl_df.pos_gene
    dist[is_right_of_eqtl] = eqtl_df[is_right_of_eqtl].pos_gene - (eqtl_df[is_right_of_eqtl].pos_eqtl + bin_size)
    dist[is_exact] = 0
    return dist

# %%
np.median(dist_to_eqtl(sig_eqtl.query('is_cis')))
# Out:
# 155021.0

# %%
np.mean(dist_to_eqtl(sig_eqtl.query('is_cis')) == 0)
# Out:
# 0.2772963604852686

# %%
fig, ax = plt.subplots()
ax.hist(dist_to_eqtl(sig_eqtl.query('is_cis')), bins=100, range=(0, 2e6));
ax.set_xlabel('Distance from cis-eQTL peak to gene (Mb)')
ax.set_ylabel('cis-eQTLs (count)')
plt.savefig(os.path.join(snakemake.output[0], 'cis_eqtl_dist_hist.svg'))

# %%
fig, axes = chrom_axes_boilerplate(chrom_sizes, figsize=(10, 3))
axes = axes.ravel()
for (chrom, eqtls), ax in zip(sig_eqtl.query('~is_cis').groupby('chrom_eqtl'), axes):
    sns.histplot(
        x='pos_eqtl',
        data=eqtls,
        bins=np.arange(0, chrom_sizes[chrom], 5e5),
        ax=ax,
    )
axes[0].set_ylabel('eQTLs (count, stacked)')
axes[0].axvspan(25.2e6, 27.2e6, color=pal[2], alpha=0.1, zorder=0)
axes[0].axvspan(14e6, 22e6, color=pal[3], alpha=0.1, zorder=0)
h = axes[0].get_ylim()[1]
axes[0].annotate('PSV1', xy=(26.2e6, h), ha='center')
axes[0].annotate('CPV1', xy=(18e6, h), ha='center')
axes[0].set_ylim(0, h * 1.1)
fig.supxlabel('eQTL position')
plt.tight_layout(pad=0.2)
plt.savefig(os.path.join(snakemake.output[0], 'eqtl_hist.svg'))
plt.show()

# %%
fig, axes = chrom_axes_boilerplate(chrom_sizes, figsize=(12, 3.5), nrows=2, row_ratios=(0.25, 0.75))
axes = axes.T

for (chrom, eqtls), ax_col in zip(sig_eqtl_celltype.query('~is_cis').groupby('chrom_eqtl'), axes):
    sns.histplot(
        x='pos_eqtl',
        hue='cluster',
        data=eqtls,
        bins=np.arange(0, chrom_sizes[chrom], 5e5),
        ax=ax_col[0],
        hue_order=['Sperm', 'Vegetative', 'Both'],
        multiple="stack"
    )
    sns.histplot(
        x='pos_eqtl',
        hue='cluster',
        data=eqtls,
        bins=np.arange(0, chrom_sizes[chrom], 5e5),
        ax=ax_col[1],
        hue_order=['Sperm', 'Vegetative', 'Both'],
        multiple="stack"
    )
    ax_col[0].legend_.remove()
    ax_col[0].set_ylabel('')
    ax_col[1].set_ylabel('')
    ax_col[0].tick_params(bottom=False) 
    ax_col[0].spines.bottom.set_visible(False)
    ax_col[1].spines.top.set_visible(False)
    d = .5  # proportion of vertical to horizontal extent of the slanted line
    kwargs = dict(marker=[(-1, -d), (1, d)], markersize=12,
                  linestyle="none", color='k', mec='k', mew=1, clip_on=False)
    ax_col[0].plot([0, 1], [0, 0], transform=ax_col[0].transAxes, **kwargs)
    ax_col[1].plot([0, 1], [1, 1], transform=ax_col[1].transAxes, **kwargs)
    if chrom != 'Chr5':
        ax_col[1].legend_.remove()
fig.supylabel('eQTLs (count, stacked)')
axes[0][0].axvspan(25e6, 27e6, color=pal[2], alpha=0.2, zorder=0)
axes[0][0].axvspan(14e6, 20e6, color=pal[3], alpha=0.2, zorder=0)
axes[0][1].axvspan(25e6, 27e6, color=pal[2], alpha=0.2, zorder=0)
axes[0][1].axvspan(14e6, 20e6, color=pal[3], alpha=0.2, zorder=0)
h = axes[0][0].get_ylim()[1]
axes[0][0].annotate('PSV1', xy=(26e6, h), ha='center', va='top')
axes[0][0].annotate('CPV1', xy=(17e6, h), ha='center', va='top')
axes[0][0].set_ylim(240, 280)
axes[0][1].set_ylim(0, 120)

fig.supxlabel('eQTL position')
plt.tight_layout(pad=0.1)
plt.savefig(os.path.join(snakemake.output[0], 'eqtl_hist_celltype.svg'))
plt.show()

# %%
cis_qtl_genes = sig_eqtl_celltype.query('is_cis').gene_id.unique()

cis_qtl_gene_exprs = exprs_mat.loc[cis_qtl_genes]
av_exprs = cis_qtl_gene_exprs.T.groupby(cis_qtl_gene_exprs.columns.map(cb_stats.celltype_cluster)).mean().T
av_exprs['logFC'] = av_exprs[1] - av_exprs[0]
av_exprs['cis_eqtl_celltype'] = av_exprs.index.map(sig_eqtl_celltype.query('is_cis').set_index('gene_id').cluster)

ax = sns.histplot(
    x='logFC',
    hue='cis_eqtl_celltype',
    data=av_exprs,
    common_norm=False,
    stat='density',
    hue_order=['Sperm', 'Vegetative'],
)
ax.set_xlabel('Log2 fold change in expression between sperm and vegetative nuclei')
ax.set_ylabel('Genes (density)')
ax.legend_.set_title('Nucleus-type of cis-eQTL')
ax.set_xlim(-5, 5)
plt.savefig(os.path.join(snakemake.output[0], 'cis_eqtl_expression.svg'))

# %%
eqtl_res_exp1 = pd.read_csv(snakemake.input.eqtls.replace('db1', 'many'), sep='\t', dtype={'chrom': str})
sig_eqtl_exp1 = call_lod_peaks(eqtl_res_exp1, snakemake.input.gtf)

# %%
venn2(
    [set(sig_eqtl.query('is_cis').gene_id.unique()),
     set(sig_eqtl_exp1.query('is_cis & db1_pval < 0.05').gene_id.unique())],
    set_labels=['Db-1 vs Col-0\n(exp. 2)', 'Db-1 vs Col-0\n(exp. 1)',],
    set_colors=[pal[0], pal[-2]]
)
plt.savefig(os.path.join(snakemake.output[0], 'cis_dataset_overlap.svg'))
plt.show()

# %%
venn3(
    [set(sig_eqtl.query('~is_cis & chrom_eqtl == "Chr1" & start_eqtl < 26.2e6 < end_eqtl').gene_id.unique()),
     set(sig_eqtl_exp1.query('~is_cis & chrom_eqtl == "Chr1" & start_eqtl < 26.2e6 < end_eqtl & db1_pval < 0.05').gene_id.unique()),
     set(sig_eqtl_exp1.query('~is_cis & chrom_eqtl == "Chr1" & start_eqtl < 26.2e6 < end_eqtl & rubezhnoe1_pval < 0.05').gene_id.unique())],
    set_labels=['Db-1 vs Col-0\n(exp. 2)', 'Db-1 vs Col-0\n(exp. 1)', 'Rubezhnoe-1 vs Col-0\n(exp. 1)'],
    set_colors=[pal[0], pal[-2], pal[3]]
)
plt.savefig(os.path.join(snakemake.output[0], 'trans_dataset_overlap.svg'))
plt.show()

# %%
fig, ax = plt.subplots(figsize=(5, 5))
sns.scatterplot(
    y=-np.log10(sig_eqtl_celltype.query('~is_cis & chrom_eqtl == "Chr1" & start_eqtl < 26.2e6 < end_eqtl').lrt_pval),
    x=sig_eqtl_celltype.query('~is_cis & chrom_eqtl == "Chr1" & start_eqtl < 26.2e6 < end_eqtl').hap2_coef,
    hue=sig_eqtl_celltype.gene_id.isin(sig_eqtl_exp1.query('~is_cis & chrom_eqtl == "Chr1" & start_eqtl < 26.2e6 < end_eqtl').gene_id.unique()),
    hue_order=[False, True],
    palette=pal[:2]
)
ax.legend_.remove()
ax.set_ylabel('-log10 FDR')
ax.set_xlabel('Estimated gene expression change\ncaused by PSV1 haplotype (log2 scale)')
ax.set_title('Effect of PSV1 haplotype on gene expression (Db-1 vs. Col-0)')
plt.savefig(os.path.join(snakemake.output[0], f'volcano_plot.svg'))

# %%
gene_locs = parse_gene_positions(snakemake.input.gtf)

eqtl_plotter = create_eqtl_plotter(
    eqtl_res,
    sig_eqtl,
    gene_locs,
    col_mapper={'lrt_pval': 'Db-1'},
    palette=pal[:1]
)

eqtl_plotter_celltype = create_eqtl_plotter(
    eqtl_res,
    sig_eqtl_celltype,
    gene_locs,
    col_mapper={'cluster_lrt_pval': 'Db-1 (all cell-types)',
                'hap2_x_cluster1_pval': 'Sperm nuclei',
                'hap2_x_cluster2_pval': 'Vegetative nuclei'},
    palette=['#252525'] + pal[:2]
)

# %%
eqtl_plotter_celltype('AT1G14420')
plt.savefig(os.path.join(snakemake.output.figures, f'pll1_manhattan_block.svg'))

# %%
eqtl_plotter_celltype('AT3G60460')
plt.savefig(os.path.join(snakemake.output.figures, f'duo1_manhattan_block.svg'))

# %%
haplotype_plotter = create_haplotype_expression_plotter(
    exprs_mat, eqtl_res, hap_probs, cb_stats, gene_locs,
)

# %%
for gene_id, gene_name in zip(['AT1G50490', 'AT5G06150', 'AT1G20930', 'AT1G20610', 'AT3G60460', 'AT1G19890', 'AT3G04620', 'AT2G17180', 'AT4G35280', 'AT4G35700', 'AT3G50310'],
                              ['UBC20', 'CYCB1;2', 'CDKB2;2', 'CYCB2;3', 'DUO1', 'MGH3', 'DAN1', 'DAZ1', 'DAZ2', 'DAZ3', 'MAPKKK20']):

    ax = haplotype_plotter(
        gene_id,
        x='haplotype',
        hue='celltype',
        haplotype='specified',
        haplotype_chrom='Chr1',
        haplotype_pos=26175000,
        cut=0,
        scale='width',
        order=['Parent 1', 'Parent 2'],
        figsize=(3, 3)
    )
    ax.set_title(gene_name)
    plt.savefig(os.path.join(snakemake.output[0], f'haplo_exprs_{gene_name}.svg'))
    plt.show()
# Out:
# /netscratch/dep_mercier/grp_schneeberger/projects/Athal/Matt_snRNAseq_analysis/diploid_starsolo_pipeline/scripts/singlecell_snptools/plot.py:246: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   sns.violinplot(
# /netscratch/dep_mercier/grp_schneeberger/projects/Athal/Matt_snRNAseq_analysis/diploid_starsolo_pipeline/scripts/singlecell_snptools/plot.py:246: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   sns.violinplot(
# /netscratch/dep_mercier/grp_schneeberger/projects/Athal/Matt_snRNAseq_analysis/diploid_starsolo_pipeline/scripts/singlecell_snptools/plot.py:246: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   sns.violinplot(
# ...

# %%
haplotype_plotter('AT1G14420', hue='celltype', cut=0, haplotype='best_hit', figsize=(4, 4))
plt.savefig(os.path.join(snakemake.output.figures, f'haplo_exprs_pll1.svg'))
