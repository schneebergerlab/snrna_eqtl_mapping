# %%
######## snakemake preamble start (automatically inserted, do not edit) ########
import sys; sys.path.extend(['/netscratch/dep_mercier/grp_schneeberger/bin/bin_matt/conda_envs/snakemake8/lib/python3.12/site-packages', '/netscratch/dep_mercier/grp_schneeberger/projects/Athal/Matt_snRNAseq_analysis/diploid_starsolo_pipeline/rules/notebook_templates']); import pickle; snakemake = pickle.loads(b'\x80\x04\x95\xe4\x06\x00\x00\x00\x00\x00\x00\x8c\x10snakemake.script\x94\x8c\tSnakemake\x94\x93\x94)\x81\x94}\x94(\x8c\x05input\x94\x8c\x0csnakemake.io\x94\x8c\nInputFiles\x94\x93\x94)\x81\x94(\x8c\x13eqtls/col0xmany.tsv\x94\x8c)aligned_data/reference/col0xmany_starsolo\x94\x8c\x1bcb_crossovers/col0xmany.tsv\x94\x8c\x16cb_stats/col0xmany.tsv\x94\x8c.annotation/reference/vcf/col0xmany.syri.vcf.gz\x94\x8c\x17../annotations/col0.gtf\x94e}\x94(\x8c\x06_names\x94}\x94(\x8c\x05eqtls\x94K\x00N\x86\x94\x8c\x0bsolo_output\x94K\x01N\x86\x94\x8c\x02co\x94K\x02N\x86\x94\x8c\x08cb_stats\x94K\x03N\x86\x94\x8c\x03vcf\x94K\x04N\x86\x94\x8c\x06gtf_fn\x94K\x05N\x86\x94u\x8c\x12_allowed_overrides\x94]\x94(\x8c\x05index\x94\x8c\x04sort\x94eh!\x8c\tfunctools\x94\x8c\x07partial\x94\x93\x94h\x06\x8c\x19Namedlist._used_attribute\x94\x93\x94\x85\x94R\x94(h\')}\x94\x8c\x05_name\x94h!sNt\x94bh"h%h\'\x85\x94R\x94(h\')}\x94h+h"sNt\x94bh\x13h\nh\x15h\x0bh\x17h\x0ch\x19h\rh\x1bh\x0eh\x1dh\x0fub\x8c\x06output\x94h\x06\x8c\x0bOutputFiles\x94\x93\x94)\x81\x94\x8c!figures/hotspot_figures_col0xmany\x94a}\x94(h\x11}\x94\x8c\x07figures\x94K\x00N\x86\x94sh\x1f]\x94(h!h"eh!h%h\'\x85\x94R\x94(h\')}\x94h+h!sNt\x94bh"h%h\'\x85\x94R\x94(h\')}\x94h+h"sNt\x94bh8h5ub\x8c\x06params\x94h\x06\x8c\x06Params\x94\x93\x94)\x81\x94}\x94(h\x11}\x94h\x1f]\x94(h!h"eh!h%h\'\x85\x94R\x94(h\')}\x94h+h!sNt\x94bh"h%h\'\x85\x94R\x94(h\')}\x94h+h"sNt\x94bub\x8c\twildcards\x94h\x06\x8c\tWildcards\x94\x93\x94)\x81\x94\x8c\tcol0xmany\x94a}\x94(h\x11}\x94\x8c\x04cond\x94K\x00N\x86\x94sh\x1f]\x94(h!h"eh!h%h\'\x85\x94R\x94(h\')}\x94h+h!sNt\x94bh"h%h\'\x85\x94R\x94(h\')}\x94h+h"sNt\x94b\x8c\x04cond\x94hVub\x8c\x07threads\x94K\x01\x8c\tresources\x94h\x06\x8c\tResources\x94\x93\x94)\x81\x94(K\x01K\x01\x8c\x04/tmp\x94e}\x94(h\x11}\x94(\x8c\x06_cores\x94K\x00N\x86\x94\x8c\x06_nodes\x94K\x01N\x86\x94\x8c\x06tmpdir\x94K\x02N\x86\x94uh\x1f]\x94(h!h"eh!h%h\'\x85\x94R\x94(h\')}\x94h+h!sNt\x94bh"h%h\'\x85\x94R\x94(h\')}\x94h+h"sNt\x94bhmK\x01hoK\x01hqhjub\x8c\x03log\x94h\x06\x8c\x03Log\x94\x93\x94)\x81\x94}\x94(h\x11}\x94h\x1f]\x94(h!h"eh!h%h\'\x85\x94R\x94(h\')}\x94h+h!sNt\x94bh"h%h\'\x85\x94R\x94(h\')}\x94h+h"sNt\x94bub\x8c\x06config\x94}\x94(\x8c\x12reference_genotype\x94\x8c\x04col0\x94\x8c\x10genome_fasta_fns\x94}\x94(\x8c\x04col0\x94\x8c\x16../annotations/col0.fa\x94\x8c\x03db1\x94\x8c\x15../annotations/db1.fa\x94\x8c\x04kar1\x94\x8c\x16../annotations/kar1.fa\x94\x8c\nrubezhnoe1\x94\x8c\x1c../annotations/rubezhnoe1.fa\x94\x8c\x03ms0\x94\x8c\x15../annotations/ms0.fa\x94\x8c\x04tsu0\x94\x8c\x16../annotations/tsu0.fa\x94u\x8c\x07gtf_fns\x94}\x94\x8c\x04col0\x94\x8c\x17../annotations/col0.gtf\x94s\x8c\x11barcode_whitelist\x94\x8c#../annotations/3M-february-2018.txt\x94u\x8c\x04rule\x94\x8c\x0fhotspot_figures\x94\x8c\x0fbench_iteration\x94N\x8c\tscriptdir\x94\x8c\x81/netscratch/dep_mercier/grp_schneeberger/projects/Athal/Matt_snRNAseq_analysis/diploid_starsolo_pipeline/rules/notebook_templates\x94ub.'); from snakemake.logging import logger; logger.printshellcmds = True; import os; os.chdir(r'/netscratch/dep_mercier/grp_schneeberger/projects/Athal/Matt_snRNAseq_analysis/diploid_starsolo_pipeline/pipeline');
######## snakemake preamble end #########

# %%
import sys
import os
import re
from copy import copy
from io import StringIO
from glob import glob
import random
import itertools as it
import warnings
from collections import Counter, defaultdict
from contextlib import contextmanager

import numpy as np
import pandas as pd
from scipy import stats
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap, Normalize
from matplotlib.cm import ScalarMappable
from matplotlib.patches import Rectangle
import seaborn as sns

import pysam
from sklearn.decomposition import PCA, TruncatedSVD
import statsmodels.api as sm
from statsmodels.stats.multitest import fdrcorrection

sys.path.extend([os.path.abspath('../scripts/')])


from singlecell_snptools.io import get_gene_locations, get_chrom_sizes
from singlecell_snptools.exprs import read_mmformat

## Default plotting params

# %matplotlib inline
sns.set(font='Arial')
plt.rcParams['svg.fonttype'] = 'none'
style = sns.axes_style('white')
style.update(sns.axes_style('ticks'))
style['xtick.major.size'] = 1
style['ytick.major.size'] = 1
sns.set(font_scale=1, style=style)
pal = sns.color_palette(['#0072b2', '#d55e00', '#009e73', '#f0e442', '#cc79a7', '#56b4e9', '#e69f00'])
cmap = ListedColormap(pal.as_hex())
sns.set_palette(pal)
sns.palplot(pal)
plt.show()

# %%
if not os.path.exists(snakemake.output[0]):
    os.mkdir(snakemake.output[0])

# %%
eqtl_res = pd.read_csv('eqtls/col0xdb1.eqtls.tsv', sep='\t', dtype={'chrom': str})
chrom_sizes = eqtl_res.groupby('chrom').pos.max().to_dict()
gene_locs = get_gene_locations('../annotations/col0_cc.gtf')

eqtl_res.head()
# Out:
#   chrom  pos    gene_id  lod_score  lrt_pval  hap2_pval  hap2_coef  \
# 0  Chr1    0  AT1G01020   0.021900       1.0        1.0   0.004470
# 1  Chr1    0  AT1G01040   0.108400       1.0        1.0   0.008861
# 2  Chr1    0  AT1G01100   0.008775       1.0        1.0   0.002367
# 3  Chr1    0  AT1G01260   0.352300       1.0        1.0   0.014900
# 4  Chr1    0  AT1G01310   0.939500       1.0        1.0   0.042330
#
#    cluster_lod_score  cluster_lrt_pval  hap2_x_cluster1_pval  \
# 0            0.09489               1.0                   1.0
# 1            0.16550               1.0                   1.0
# 2            0.20840               1.0                   1.0
# 3            0.95120               1.0                   1.0
# 4            2.14300               1.0                   1.0
#
#    hap2_x_cluster2_pval  hap2_x_cluster1_coef  hap2_x_cluster2_coef
# 0                   1.0              0.000122               0.01814
# ...

# %%
import numpy as np
from scipy.signal import find_peaks
from scipy.ndimage import convolve
import pandas as pd

LOD_THRESHOLD = 3.0
FDR_THRESHOLD = 0.05

def find_lod_peaks(eqtl_data, lod_threshold=LOD_THRESHOLD, rel_lod_threshold=0.1,
                   fdr_threshold=FDR_THRESHOLD,
                   rel_prominence=0.25, lod_drop=1.5,
                   min_dist=3_000_000, bin_size=25_000,
                   cell_type_specific=False):
    min_dist = min_dist // bin_size
    peaks = []
    for _, chrom_eqtl_data in eqtl_data.groupby('chrom'):
        chrom_eqtl_data = chrom_eqtl_data.sort_values('pos')
        lod = chrom_eqtl_data.lod_score.values if not cell_type_specific else np.maximum(chrom_eqtl_data.cluster_lod_score.values, chrom_eqtl_data.lod_score.values)
        lod[lod < lod_threshold] = -np.inf
        fdr = chrom_eqtl_data.lrt_pval.values if not cell_type_specific else np.minimum(chrom_eqtl_data.cluster_lrt_pval.values, chrom_eqtl_data.lrt_pval.values) * 2
        peak_idx, _ = find_peaks(
            np.insert(lod, [0, len(lod)], [-np.inf, -np.inf]), # insert infs at beginning and end of chromosome to prevent prominence edge effects
            height=max(lod_threshold, max(lod) * rel_lod_threshold),
            prominence=max(lod) * rel_prominence,
            distance=min_dist
        )
        peak_idx = peak_idx - 1
        peak_idx = [i for i in peak_idx if fdr[i] < fdr_threshold]
        l_ci_idx = 0
        r_ci_idx = len(chrom_eqtl_data) - 1
        for p_idx in peak_idx:
            drop_thresh = lod[p_idx] - lod_drop
            for r_ci_idx in range(p_idx, len(lod)):
                if lod[r_ci_idx] <= drop_thresh:
                    break
            for l_ci_idx in reversed(range(0, p_idx)):
                if lod[l_ci_idx] <= drop_thresh:
                    break
            eqtl_peak = chrom_eqtl_data.iloc[p_idx].copy()
            eqtl_peak['start'] = chrom_eqtl_data.iloc[l_ci_idx].pos
            eqtl_peak['end'] = chrom_eqtl_data.iloc[r_ci_idx].pos + bin_size
            peaks.append(eqtl_peak)
    peaks = pd.DataFrame(
        peaks,
        columns=eqtl_data.columns.tolist() + ['start', 'end'],
    )
    peaks['pos_eqtl'] = peaks.pop('pos').astype(int)
    peaks['start'] = peaks.start.astype(int)
    peaks['end'] = peaks.end.astype(int)
    return peaks

# %%
sig_eqtl_celltype = pd.merge(
    eqtl_res.groupby('gene_id', as_index=False).apply(find_lod_peaks, cell_type_specific=True).reset_index(drop=True),
    gene_locs,
    left_on='gene_id',
    right_index=True,
    how='left',
    suffixes=['_eqtl', '_gene']
)
sig_eqtl_celltype = sig_eqtl_celltype.assign(
    pos_gene = (sig_eqtl_celltype.start_gene.astype(int) + sig_eqtl_celltype.end_gene.astype(int)) // 2,
)
sig_eqtl_celltype['is_cis'] = sig_eqtl_celltype.eval('chrom_eqtl == chrom_gene & (start_eqtl - 3e6) <= pos_gene <= (end_eqtl + 3e6)')
sig_eqtl_celltype['cluster'] = sig_eqtl_celltype.eval('(hap2_x_cluster1_pval < 0.05) + (hap2_x_cluster2_pval < 0.05) * 2').map({0: 'Neither', 1: 'Sperm', 2: 'Vegetative', 3: 'Both'})
sig_eqtl_celltype = sig_eqtl_celltype.query('cluster != "Neither"')
sig_eqtl_celltype.head()
# Out:
#   chrom_eqtl    gene_id  lod_score      lrt_pval     hap2_pval  hap2_coef  \
# 0       Chr1  AT1G01310     0.9618  1.000000e+00  1.000000e+00    0.04174
# 1       Chr1  AT1G01320    35.3300  2.146000e-32  2.405000e-32    0.48010
# 2       Chr1  AT1G01320     4.4880  5.099000e-03  5.176000e-03   -0.16860
# 3       Chr1  AT1G01460     2.3250  9.399000e-01  9.476000e-01    0.06652
# 4       Chr1  AT1G01510     1.6070  1.000000e+00  1.000000e+00    0.04028
#
#    cluster_lod_score  cluster_lrt_pval  hap2_x_cluster1_pval  \
# 0              4.498      2.213000e-02          1.000000e+00
# 1             46.700      1.306000e-42          1.172000e-43
# 2              6.116      6.766000e-04          1.308000e-04
# 3              7.686      4.038000e-05          1.000000e+00
# 4              5.572      2.984000e-03          1.000000e+00
#
#    hap2_x_cluster2_pval  ...  hap2_x_cluster2_coef  start_eqtl  end_eqtl  \
# 0              0.028210  ...               0.17900    24475000  27075000
# ...

# %%
from scipy.io import mmread

def read_index(idx_fn):
    with open(idx_fn) as f:
        idx = [r.strip().split('\t')[0] for r in f.readlines()]
    return np.array(idx)


def lognormalise_exprs(mtx, alpha=0.25):
    umi_counts = mtx.sum(0)
    sf = (umi_counts / np.mean(umi_counts))
    ln_mtx = np.log2(mtx / sf + (1.0 / (4 * alpha)))
    sf = sf.rename('size_factors')
    return ln_mtx, sf


def read_mmformat(mtx_dirs, cb_whitelist, feat_filt=10,
                  mtx_fn='matrix.mtx',
                  barcode_fn='barcodes.tsv',
                  feature_fn='features.tsv'):
    mtxs = []
    for mtx_dir in mtx_dirs:
        mtx = mmread(os.path.join(mtx_dir, mtx_fn)).tocsr()
        bc_mask = np.array(mtx.sum(axis=0) > 0).ravel()
        mtx = mtx[:, bc_mask]
        barcodes = read_index(os.path.join(mtx_dir, barcode_fn))[bc_mask]
        features = read_index(os.path.join(mtx_dir, feature_fn))
        mtx = pd.DataFrame.sparse.from_spmatrix(mtx, columns=barcodes, index=features)
        mtx = mtx.loc[:, mtx.columns.isin(cb_whitelist)]
        mtxs.append(mtx)
    mtx = pd.concat(mtxs, axis=1).fillna(0)
    mtx = mtx.loc[np.count_nonzero(mtx, axis=1) > feat_filt]
    mtx = mtx.sparse.to_dense().astype(np.float32)
    return mtx

# %%
cb_stats = pd.read_csv(
    'cb_stats/col0xdb1.tsv',
    header=0,
    index_col=0,
    sep='\t',
    usecols=['cb', 'cluster'],
)
cb_whitelist = sorted(cb_stats.query('cluster == "hq"').index.tolist())

exprs_mat = read_mmformat(['aligned_data/diploid/col0xdb1.col0__vs__db1_genecounts'], cb_whitelist)
exprs_mat = exprs_mat.loc[:, cb_whitelist]
ln_exprs_mat, sf = lognormalise_exprs(exprs_mat)

hap_probs = pd.concat((
    pd.read_csv(fn, sep='\t', header=[0, 1], index_col=[0, 1])
    for fn in glob('cb_crossovers/col0xdb1.col0__vs__db1.co_probs.tsv')
), axis=0)
hap_probs.columns.set_names(['chrom', 'pos'], inplace=True)
hap_probs.index = hap_probs.index.droplevel(0)
hap_probs = hap_probs.loc[cb_whitelist]

covariates = pd.read_csv('eqtls/col0xdb1.covars.tsv', sep='\t', index_col=0)

# %%
sperm_mask = sorted(covariates.query('cluster1 > 0.95').index.tolist())
ln_exprs_mat_sperm = ln_exprs_mat.loc[:, sperm_mask]
hap_probs_sperm = hap_probs.loc[sperm_mask]

# %%
psv1_mask = sorted(sig_eqtl_celltype.query('~is_cis & chrom_eqtl == "Chr1" & (start_eqtl) <= 7000000 <= (end_eqtl) & cluster == "Sperm"').gene_id.unique().tolist())
ln_exprs_mat_psv1 = ln_exprs_mat_sperm.loc[psv1_mask]

psv1_pca = PCA(n_components=5, svd_solver='arpack')
psv1_comps = pd.DataFrame(
    psv1_pca.fit_transform(ln_exprs_mat_psv1.T),
    columns=[f'PC{i}' for i in range(1, 6)],
    index=ln_exprs_mat_psv1.columns
)

# %%
LOD = 2 * np.log(10)

def haplotype_linear_model(pcs, hap_probs, covariates=None):
    res = []
    # generate nested models without haplotypes for likelihood ratio test
    nested_models = {}
    for pc, endog in pcs.items():
        if covariates is not None:
            all_covariates = sm.add_constant(pd.concat([pcs.loc[:, pcs.columns != pc], covariates], axis=1))
        else:
            all_covariates = sm.add_constant(pcs.loc[:, pcs.columns != pc])
        m = sm.OLS(endog, all_covariates, hasconst=True).fit(disp=0)
        nested_models[pc] = (m, all_covariates)
    for (chrom, pos), haplo in hap_probs.items():
        for pc, endog in pcs.items():
            m_nest, covariates = nested_models[pc]
            exog = pd.concat([haplo.rename('haplo').to_frame(), covariates], axis=1)
            m_full = sm.OLS(endog, exog, hasconst=True).fit(disp=0)
            lr, lrtest_pval, _ = m_full.compare_lr_test(m_nest)
            res.append([chrom, int(pos), pc, lr / LOD, lrtest_pval])
    res = pd.DataFrame(res, columns=['chrom', 'pos', 'gene_id',
                                     'lod_score', 'lrt_pval'])
    return res

# %%
res = haplotype_linear_model(psv1_comps, hap_probs_sperm, hap_probs_sperm[('Chr1', '26175000')].rename('psv1').to_frame())

# %%
res.groupby('gene_id', as_index=False).apply(find_lod_peaks).reset_index(drop=True)
# Out:
#    chrom gene_id  lod_score      lrt_pval     start       end  pos_eqtl
# 0   Chr1     PC1  39.315297  2.853470e-41   6925000   7900000   7450000
# 1   Chr3     PC1  16.208636  5.638624e-18  20850000  22450000  21350000
# 2   Chr5     PC1   7.431435  4.914413e-09  22125000  26525000  24300000
# 3   Chr1     PC2  29.078857  5.708035e-31   7000000   7725000   7275000
# 4   Chr1     PC3   8.220170  7.619177e-10   4325000   7800000   6675000
# 5   Chr5     PC3   3.349121  8.592365e-05   7825000   9050000   8550000
# 6   Chr1     PC4   4.921010  1.931414e-06   4900000   7950000   6025000
# 7   Chr3     PC4  15.022153  8.989433e-17  15025000  19475000  18475000
# 8   Chr3     PC5   3.760388  3.163061e-05   8775000  15650000   9975000
# 9   Chr3     PC5   4.915349  1.957798e-06  24175000  26150000  25125000
# 10  Chr4     PC5   4.347557  7.658665e-06  13550000  19300000  14800000
# 11  Chr5     PC5   3.382912  7.913332e-05   6550000   8775000   7600000

# %%
print('\n'.join(gene_locs.query('chrom=="Chr1" & 6925000 < start < 7900000').index))
# Out:
# AT1G19950
# AT1G19960
# AT1G19968
# AT1G19970
# AT1G19980
# AT1G19990
# AT1G20000
# AT1G20010
# AT1G20015
# AT1G05517
# AT1G20020
# AT1G20030
# AT1G20040
# AT1G20050
# AT1G20060
# AT1G20065
# AT1G05523
# AT1G20070
# AT1G05527
# AT1G05533
# AT1G20080
# AT1G20090
# AT1G20100
# AT1G20110
# AT1G20120
# AT1G20130
# AT1G20132
# AT1G20135
# AT1G20140
# AT1G20150
# AT1G20160
# AT1G20170
# AT1G20180
# AT1G20190
# AT1G20200
# AT1G20210
# AT1G20220
# AT1G20225
# AT1G20230
# AT1G20240
# AT1G20250
# AT1G20260
# AT1G20270
# AT1G20280
# AT1G20290
# AT1G20300
# AT1G20310
# AT1G20320
# AT1G20330
# AT1G20340
# AT1G20350
# AT1G05537
# AT1G20360
# AT1G05543
# AT1G05547
# AT1G20370
# AT1G20375
# AT1G20380
# AT1G20400
# AT1G20405
# AT1G20410
# AT1G20420
# AT1G20430
# AT1G20440
# AT1G20450
# AT1G20460
# AT1G05553
# AT1G05557
# AT1G20470
# AT1G20480
# AT1G20490
# AT1G20500
# AT1G20510
# AT1G20515
# AT1G20520
# AT1G20530
# AT1G20540
# AT1G20550
# AT1G20560
# AT1G20570
# AT1G20575
# AT1G20580
# AT1G20590
# ...

# %%
plt.plot(res.query('gene_id == "PC1"').lod_score)

# %%
def chrom_axes_boilerplate(chrom_sizes, figsize=(18, 5)):

    fig, axes = plt.subplots(
        figsize=figsize,
        ncols=len(chrom_sizes),
        width_ratios=list(chrom_sizes.values()),
        sharey='all',
    )
    for chrom, ax in zip(chrom_sizes, axes):
        ax.set_xlim(0, chrom_sizes[chrom])
        ax.set_xticks(np.arange(0, chrom_sizes[chrom], 1e7))
        ax.set_xticklabels([int(i // 1e6) for i in np.arange(0, chrom_sizes[chrom], 1e7)])
        ax.set_xlabel(f'Chromosome {chrom} (Mb)')

    plt.tight_layout()
    return fig, axes


def boot_eqtl_plotter(title=None):
    def _fdr_name_mapper(fdr_col_name):
        if fdr_col_name == 'lrt_pval_fdr':
            return 'Combined'
        else:
            return fdr_col_name.split('_', 1)[0].capitalize()

    boot_mean = boot_res[0].copy()
    for p_col in (c for c in eqtl_res.columns if c.endswith('_pval')):
        boot_mean[p_col] = stats.hmean([b[p_col].values for b in boot_res], axis=0)
        _, boot_mean[f'{p_col}_fdr'] = fdrcorrection(boot_mean[p_col])

    gene_eqtl_res = (boot_mean.melt(id_vars=['chrom', 'start', 'end'],
                                    value_vars=[c for c in boot_mean.columns if c.endswith('_fdr')],
                                    var_name='genotype',
                                    value_name='fdr'))
    if not len(gene_eqtl_res):
        raise ValueError('Gene was not tested')
    gene_eqtl_res = gene_eqtl_res.query('genotype != "wald_pval_fdr"').assign(
        genotype=gene_eqtl_res.genotype.map(_fdr_name_mapper),
        nlog10_fdr=np.negative(np.log10(gene_eqtl_res.fdr))
    )
    order = gene_eqtl_res.query('genotype != "Combined"').genotype.unique()
    order = ['Combined'] + sorted(order)

    fig, axes = chrom_axes_boilerplate(chrom_sizes, figsize=(12, 3.5))
    for (chrom, chrom_eqtl_res), ax in zip(gene_eqtl_res.groupby('chrom'), axes):
        sns.lineplot(
            x='start',
            y='nlog10_fdr',
            hue='genotype',
            data=chrom_eqtl_res,
            drawstyle='steps-post',
            ax=ax,
            hue_order=order,
            palette = ['#252525'] + pal[:len(order) - 1]
        )

    axes[0].set_ylabel('Negative log10 FDR')
    for ax in axes[:-1]:
        ax.legend_.remove()

    plt.tight_layout(pad=0.2)
    return axes

# %%
boot_eqtl_plotter()
# Out:
# array([<Axes: xlabel='Chromosome Chr1 (Mb)', ylabel='Negative log10 FDR'>,
#        <Axes: xlabel='Chromosome Chr2 (Mb)', ylabel='nlog10_fdr'>,
#        <Axes: xlabel='Chromosome Chr3 (Mb)', ylabel='nlog10_fdr'>,
#        <Axes: xlabel='Chromosome Chr4 (Mb)', ylabel='nlog10_fdr'>,
#        <Axes: xlabel='Chromosome Chr5 (Mb)', ylabel='nlog10_fdr'>],
#       dtype=object)

# %%
m = cb_genotypes.geno == 'rubezhnoe1'
y = exprs_mat.loc['AT4G21070']
y = y[m]
x = pd.concat(
    [all_covariates[['PC1', 'PC2']],
     (haplotype_blocks.loc[('Chr1', 23819823, 23878514)] == 'rubezhnoe1').astype(int).rename('rub_psv1'),
     (haplotype_blocks.loc[('Chr4', 10539057, 10558871)] == 'rubezhnoe1').astype(int).rename('rub_brca1'),
    ],
    axis=1
)
x = x[m]
x['colbrca1_x_rubpsv1'] = x.rub_psv1 * (1 - x.rub_brca1)
x['rubbrca1_x_colpsv1'] = (1 - x.rub_psv1) * x.rub_brca1

sm.OLS(y, sm.add_constant(x), hasconst=True).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              AT4G21070   R-squared:                       0.218
# Model:                            OLS   Adj. R-squared:                  0.210
# Method:                 Least Squares   F-statistic:                     29.09
# Date:                Fri, 26 Jan 2024   Prob (F-statistic):           4.52e-26
# Time:                        15:04:21   Log-Likelihood:                -1032.9
# No. Observations:                 529   AIC:                             2078.
# Df Residuals:                     523   BIC:                             2103.
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# ...

# %%
sns.violinplot(
    x='rub_psv1',
    hue='rub_brca1',
    y='AT4G21070',
    data=x.assign(AT4G21070=y),
)
# Out:
# <Axes: xlabel='rub_psv1', ylabel='AT4G21070'>
