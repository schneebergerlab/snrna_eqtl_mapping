# %%
######## snakemake preamble start (automatically inserted, do not edit) ########
import sys; sys.path.extend(['/netscratch/dep_mercier/grp_schneeberger/bin/bin_matt/conda_envs/snakemake/lib/python3.11/site-packages', '/netscratch/dep_mercier/grp_schneeberger/projects/Athal/Matt_snRNAseq_analysis/diploid_starsolo_pipeline/rules/notebook_templates']); import pickle; snakemake = pickle.loads(b'\x80\x04\x95o\x06\x00\x00\x00\x00\x00\x00\x8c\x10snakemake.script\x94\x8c\tSnakemake\x94\x93\x94)\x81\x94}\x94(\x8c\x05input\x94\x8c\x0csnakemake.io\x94\x8c\nInputFiles\x94\x93\x94)\x81\x94(\x8c\x13eqtls/col0xmany.tsv\x94\x8c\x16cb_stats/col0xmany.tsv\x94\x8c.annotation/reference/vcf/col0xmany.syri.vcf.gz\x94\x8c\x17../annotations/col0.gtf\x94e}\x94(\x8c\x06_names\x94}\x94(\x8c\x05eqtls\x94K\x00N\x86\x94\x8c\x08cb_stats\x94K\x01N\x86\x94\x8c\x03vcf\x94K\x02N\x86\x94\x8c\x06gtf_fn\x94K\x03N\x86\x94u\x8c\x12_allowed_overrides\x94]\x94(\x8c\x05index\x94\x8c\x04sort\x94eh\x1b\x8c\tfunctools\x94\x8c\x07partial\x94\x93\x94h\x06\x8c\x19Namedlist._used_attribute\x94\x93\x94\x85\x94R\x94(h!)}\x94\x8c\x05_name\x94h\x1bsNt\x94bh\x1ch\x1fh!\x85\x94R\x94(h!)}\x94h%h\x1csNt\x94bh\x11h\nh\x13h\x0bh\x15h\x0ch\x17h\rub\x8c\x06output\x94h\x06\x8c\x0bOutputFiles\x94\x93\x94)\x81\x94\x8c\x1efigures/eqtl_figures_col0xmany\x94a}\x94(h\x0f}\x94\x8c\x07figures\x94K\x00N\x86\x94sh\x19]\x94(h\x1bh\x1ceh\x1bh\x1fh!\x85\x94R\x94(h!)}\x94h%h\x1bsNt\x94bh\x1ch\x1fh!\x85\x94R\x94(h!)}\x94h%h\x1csNt\x94bh2h/ub\x8c\x06params\x94h\x06\x8c\x06Params\x94\x93\x94)\x81\x94}\x94(h\x0f}\x94h\x19]\x94(h\x1bh\x1ceh\x1bh\x1fh!\x85\x94R\x94(h!)}\x94h%h\x1bsNt\x94bh\x1ch\x1fh!\x85\x94R\x94(h!)}\x94h%h\x1csNt\x94bub\x8c\twildcards\x94h\x06\x8c\tWildcards\x94\x93\x94)\x81\x94\x8c\tcol0xmany\x94a}\x94(h\x0f}\x94\x8c\x04cond\x94K\x00N\x86\x94sh\x19]\x94(h\x1bh\x1ceh\x1bh\x1fh!\x85\x94R\x94(h!)}\x94h%h\x1bsNt\x94bh\x1ch\x1fh!\x85\x94R\x94(h!)}\x94h%h\x1csNt\x94b\x8c\x04cond\x94hPub\x8c\x07threads\x94K\x01\x8c\tresources\x94h\x06\x8c\tResources\x94\x93\x94)\x81\x94(K\x01K\x01\x8c\x04/tmp\x94e}\x94(h\x0f}\x94(\x8c\x06_cores\x94K\x00N\x86\x94\x8c\x06_nodes\x94K\x01N\x86\x94\x8c\x06tmpdir\x94K\x02N\x86\x94uh\x19]\x94(h\x1bh\x1ceh\x1bh\x1fh!\x85\x94R\x94(h!)}\x94h%h\x1bsNt\x94bh\x1ch\x1fh!\x85\x94R\x94(h!)}\x94h%h\x1csNt\x94bhgK\x01hiK\x01hkhdub\x8c\x03log\x94h\x06\x8c\x03Log\x94\x93\x94)\x81\x94}\x94(h\x0f}\x94h\x19]\x94(h\x1bh\x1ceh\x1bh\x1fh!\x85\x94R\x94(h!)}\x94h%h\x1bsNt\x94bh\x1ch\x1fh!\x85\x94R\x94(h!)}\x94h%h\x1csNt\x94bub\x8c\x06config\x94}\x94(\x8c\x12reference_genotype\x94\x8c\x04col0\x94\x8c\x10genome_fasta_fns\x94}\x94(\x8c\x04col0\x94\x8c\x16../annotations/col0.fa\x94\x8c\x03db1\x94\x8c\x15../annotations/db1.fa\x94\x8c\x04kar1\x94\x8c\x16../annotations/kar1.fa\x94\x8c\nrubezhnoe1\x94\x8c\x1c../annotations/rubezhnoe1.fa\x94\x8c\x03ms0\x94\x8c\x15../annotations/ms0.fa\x94\x8c\x04tsu0\x94\x8c\x16../annotations/tsu0.fa\x94u\x8c\x07gtf_fns\x94}\x94\x8c\x04col0\x94\x8c\x17../annotations/col0.gtf\x94s\x8c\x11barcode_whitelist\x94\x8c#../annotations/3M-february-2018.txt\x94u\x8c\x04rule\x94\x8c\x0ceqtl_figures\x94\x8c\x0fbench_iteration\x94N\x8c\tscriptdir\x94\x8c\x81/netscratch/dep_mercier/grp_schneeberger/projects/Athal/Matt_snRNAseq_analysis/diploid_starsolo_pipeline/rules/notebook_templates\x94ub.'); from snakemake.logging import logger; logger.printshellcmds = True; import os; os.chdir(r'/netscratch/dep_mercier/grp_schneeberger/projects/Athal/Matt_snRNAseq_analysis/diploid_starsolo_pipeline/pipeline');
######## snakemake preamble end #########

# %%
import sys
import os
import re
from copy import copy
from io import StringIO
from glob import glob
import random
import itertools as it
import warnings
from collections import Counter, defaultdict
from contextlib import contextmanager

import numpy as np
import pandas as pd
from scipy import stats
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap, Normalize
from matplotlib.cm import ScalarMappable
from matplotlib.patches import Rectangle
import seaborn as sns

import pysam

sys.path.extend([os.path.abspath('../scripts/')])

from singlecell_snptools.eqtl import find_lod_peaks
from singlecell_snptools.crossovers import get_haplotype_blocks
from singlecell_snptools.io import get_gene_locations, get_chrom_sizes
from singlecell_snptools.exprs import read_mmformat

## Default plotting params

# %matplotlib inline
sns.set(font='Arial')
plt.rcParams['svg.fonttype'] = 'none'
style = sns.axes_style('white')
style.update(sns.axes_style('ticks'))
style['xtick.major.size'] = 1
style['ytick.major.size'] = 1
sns.set(font_scale=1, style=style)
pal = sns.color_palette(['#0072b2', '#d55e00', '#009e73', '#f0e442', '#cc79a7', '#56b4e9', '#e69f00'])
cmap = ListedColormap(pal.as_hex())
sns.set_palette(pal)
sns.palplot(pal)
plt.show()

# %%
if not os.path.exists(snakemake.output[0]):
    os.mkdir(snakemake.output[0])

# %%
eqtl_res = pd.read_csv(snakemake.input.eqtls, sep='\t', dtype={'chrom': str})
chrom_sizes = eqtl_res.groupby('chrom').end.max().to_dict()
gene_locs = get_gene_locations(snakemake.input.gtf_fn)

eqtl_res.head()
# Out:
#   chrom  start     end    gene_id  lod_score  lrt_pval  wald_pval  db1_pval  \
# 0  Chr1      0  130263  AT1G01320     5.0660  0.000292   0.000308  0.009338
# 1  Chr1      0  130263  AT1G01340     2.2490  0.065710   0.067080  0.112700
# 2  Chr1      0  130263  AT1G01880     0.5926  0.741700   0.743900  0.384700
# 3  Chr1      0  130263  AT1G02140     1.7110  0.162900   0.165300  0.075810
# 4  Chr1      0  130263  AT1G02500     0.3582  0.895200   0.896200  0.633300
#
#    kar1_pval  ms0_pval  rubezhnoe1_pval  tsu0_pval  lrt_fdr  wald_fdr  \
# 0    0.02622    0.3624         0.001273     0.5838  0.01304   0.01377
# 1    0.01092    0.3142         0.583000     0.9714  0.41310   0.42170
# 2    0.99470    0.8623         0.953900     0.1647  0.92030   0.92300
# 3    0.29900    0.1305         0.259200     0.8393  0.58240   0.59090
# 4    0.37810    0.7462         0.488300     0.8217  0.96980   0.97100
#
#    db1_fdr  kar1_fdr  ms0_fdr  rubezhnoe1_fdr  tsu0_fdr
# ...

# %%
hap_blocks = (eqtl_res.groupby(['chrom', 'start', 'end'])
                      .first()
                      .index.to_frame()
                      .reset_index(drop=True))

fig, ax = plt.subplots()
logbins = np.logspace(np.log10(1), np.log10(1e6), 50)
ax.hist(x=hap_blocks.end - hap_blocks.start, bins=logbins)
ax.set_xscale('log')
ax.set_ylabel('Haplotype blocks (count)')
ax.set_xlabel('Haplotype block length')
plt.savefig(os.path.join(snakemake.output[0], 'haplotype_block_length.svg'))
plt.show()

# %%
import numpy as np
from scipy.signal import find_peaks
import pandas as pd


def find_lod_peaks(eqtl_data, nlog10fdr_threshold=2, rel_prominence=0.25, lod_drop=1.5, min_dist=250):
    peaks = []
    for _, chrom_eqtl_data in eqtl_data.groupby('chrom'):
        chrom_eqtl_data = chrom_eqtl_data.sort_values('start')
        lod = chrom_eqtl_data.lod_score.values
        fdr = -np.log10(chrom_eqtl_data.lrt_fdr.values)
        peak_idx, peak_stats = find_peaks(
            fdr,
            height=nlog10fdr_threshold,
            prominence=max(max(fdr) * rel_prominence, nlog10fdr_threshold),
            distance=min_dist
        )
        for p_idx in peak_idx:
            drop_thresh = lod[p_idx] - lod_drop
            for r_ci_idx in range(p_idx, len(lod)):
                if lod[r_ci_idx] <= drop_thresh:
                    break
            for l_ci_idx in reversed(range(0, p_idx)):
                if lod[l_ci_idx] <= drop_thresh:
                    break
            eqtl_peak = chrom_eqtl_data.iloc[p_idx].copy()
            eqtl_peak['pos_eqtl'] = (eqtl_peak.start + eqtl_peak.end) // 2
            eqtl_peak['start'] = chrom_eqtl_data.iloc[l_ci_idx].start
            eqtl_peak['end'] = chrom_eqtl_data.iloc[r_ci_idx].end
            peaks.append(eqtl_peak)
    peaks =  pd.DataFrame(
        peaks,
        columns=eqtl_data.columns.tolist() + ['pos_eqtl'],
    )
    peaks['pos_eqtl'] = peaks.pos_eqtl.astype(int)
    peaks['start'] = peaks.start.astype(int)
    peaks['end'] = peaks.end.astype(int)
    peaks = peaks.loc[:, ['chrom', 'pos_eqtl'] + peaks.columns.tolist()[1:-1]]
    return peaks

# %%
sig_eqtl = pd.merge(
    eqtl_res.groupby('gene_id', as_index=False).apply(find_lod_peaks).reset_index(drop=True),
    gene_locs,
    left_on='gene_id',
    right_index=True,
    how='left',
    suffixes=['_eqtl', '_gene']
)
sig_eqtl = sig_eqtl.assign(
    pos_gene = (sig_eqtl.start_gene.astype(int) + sig_eqtl.end_gene.astype(int)) // 2,
)
sig_eqtl['is_cis'] = sig_eqtl.eval('chrom_eqtl == chrom_gene & (start_eqtl - 3e6) <= pos_gene <= (end_eqtl + 3e6)')
sig_eqtl.head()
# Out:
#   chrom_eqtl  pos_eqtl  start_eqtl  end_eqtl    gene_id  lod_score  \
# 0       Chr1  23589453    23349076  24297364  AT1G01320     11.890
# 1       Chr1  20213081    18378237  21135899  AT1G02780      6.210
# 2       Chr1   4471583     3346748   6879879  AT1G03800      6.768
# 3       Chr1  23900153    23357760  24313382  AT1G04880     13.200
# 4       Chr5  16913705    14015230  17900528  AT1G04880      5.532
#
#        lrt_pval     wald_pval  db1_pval  kar1_pval  ...   db1_fdr  kar1_fdr  \
# 0  1.480000e-10  1.697000e-10  0.000003   0.900000  ...  0.000730   0.99240
# 1  2.778000e-05  2.973000e-05  0.167700   0.152100  ...  0.735800   0.79430
# 2  8.681000e-06  9.354000e-06  0.147200   0.001984  ...  0.713400   0.20090
# 3  8.329000e-12  9.702000e-12  0.000029   0.038920  ...  0.004741   0.59640
# 4  1.127000e-04  1.197000e-04  0.003598   0.000311  ...  0.160300   0.06811
#
#    ms0_fdr  rubezhnoe1_fdr  tsu0_fdr  chrom_gene  start_gene  end_gene  \
# ...

# %%
sig_eqtl.to_csv('../../multicelltype_starsolo_pipeline/workspace/sig_eqtls.tsv', sep='\t')

# %%
fig, axes = plt.subplots(
    figsize=(10, 10),
    ncols=len(chrom_sizes),
    nrows=len(chrom_sizes),
    width_ratios=list(chrom_sizes.values()),
    height_ratios=list(chrom_sizes.values()),
    sharex='col',
    sharey='row',
)
axes = axes[::-1]
chroms = list(chrom_sizes)

CIS_RANGE = 3e6
TRANS_RANGE = np.array([22e6, 26e6])

for i, j in it.product(range(len(chrom_sizes)), repeat=2):
    c_i, c_j = chroms[i], chroms[j]
    d = sig_eqtl.query('chrom_gene == @c_i & chrom_eqtl == @c_j')
    sns.scatterplot(
        x=d.pos_eqtl,
        y=d.pos_gene,
        hue=d.is_cis,
        size=d.lod_score,
        size_norm=(0, 75),
        hue_order=[False, True],
        palette=pal[:2],
        ax=axes[i][j],
    )
    axes[i][j].errorbar(
        x=d.pos_eqtl,
        y=d.pos_gene,
        xerr=[d.pos_eqtl - d.start_eqtl,
              d.end_eqtl - d.pos_eqtl],
        color='#777777',
        zorder=0,
        linestyle='None',
        marker='None',
        alpha=0.75
    )
    try:
        axes[i][j].legend_.remove()
    except:
        pass

    if i == j:
        axes[i][j].fill_between(
            x=[0, CIS_RANGE, chrom_sizes[c_j] - CIS_RANGE, chrom_sizes[c_j]],
            y1=[0, 0, chrom_sizes[c_i] - CIS_RANGE * 2, chrom_sizes[c_i] - CIS_RANGE],
            y2=[CIS_RANGE, CIS_RANGE * 2, chrom_sizes[c_i], chrom_sizes[c_i]],
            color=pal[1],
            alpha=0.1,
            zorder=2
        )
    
    axes[i][j].set_ylim(0, chrom_sizes[c_i])
    axes[i][j].set_xlim(0, chrom_sizes[c_j])

    if c_j == 'Chr1':
        if c_i != c_j:
            axes[i][j].axvspan(22e6, 26e6, color=pal[2], alpha=0.2)
        else:
            axes[i][j].fill_between(
                x=TRANS_RANGE,
                y1=[0, 0],
                y2=TRANS_RANGE - CIS_RANGE,
                color=pal[2],
                alpha=0.2
            )
            axes[i][j].fill_between(
                x=TRANS_RANGE,
                y1=TRANS_RANGE + CIS_RANGE,
                y2=[chrom_sizes[c_i], chrom_sizes[c_i]],
                color=pal[2],
                alpha=0.2
            )

for ax, chrom in zip(axes[0], chroms):
    ax.set_xticks(np.arange(0, chrom_sizes[chrom], 1e7))
    ax.set_xticklabels([int(i // 1e6) for i in np.arange(0, chrom_sizes[chrom], 1e7)])
    ax.set_xlabel(f'{chrom} (Mb)')

for ax, chrom in zip(axes[:, 0], chroms):
    ax.set_yticks(np.arange(0, chrom_sizes[chrom], 1e7))
    ax.set_yticklabels([int(i // 1e6) for i in np.arange(0, chrom_sizes[chrom], 1e7)])
    ax.set_ylabel(f'{chrom} (Mb)')

fig.supxlabel('eQTL position')
fig.supylabel('Gene position')

plt.tight_layout(h_pad=0.1, w_pad=0.1)
#plt.savefig(os.path.join(snakemake.output[0], 'eqtl_scatterplot.svg'))
plt.show()
# Out:
# /tmp/ipykernel_10382/723303174.py:19: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(
# /tmp/ipykernel_10382/723303174.py:19: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(
# /tmp/ipykernel_10382/723303174.py:19: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(
# /tmp/ipykernel_10382/723303174.py:19: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(

# %%
def chrom_axes_boilerplate(chrom_sizes, figsize=(18, 5)):

    fig, axes = plt.subplots(
        figsize=figsize,
        ncols=len(chrom_sizes),
        width_ratios=list(chrom_sizes.values()),
        sharey='all',
    )
    for chrom, ax in zip(chrom_sizes, axes):
        ax.set_xlim(0, chrom_sizes[chrom])
        ax.set_xticks(np.arange(0, chrom_sizes[chrom], 1e7))
        ax.set_xticklabels([int(i // 1e6) for i in np.arange(0, chrom_sizes[chrom], 1e7)])
        ax.set_xlabel(f'Chromosome {chrom} (Mb)')

    plt.tight_layout()
    return fig, axes

# %%
def _fdr_name_mapper(fdr_col_name):
    if fdr_col_name == 'wald_fdr':
        return 'Combined'
    else:
        return fdr_col_name.rsplit('_', 1)[0].capitalize()

fig, axes = chrom_axes_boilerplate(chrom_sizes, figsize=(12, 3.5))

for (chrom, eqtls), ax in zip(sig_eqtl.groupby('chrom_eqtl'), axes):
    eqtls = (eqtls.query('~is_cis').melt(id_vars=['pos_eqtl'],
                       value_vars=[c for c in eqtl_res.columns if c.endswith('_fdr') and c not in ['lrt_fdr', 'wald_fdr']],
                       var_name='genotype',
                       value_name='fdr')
                  .query('fdr < 0.05'))
    eqtls['genotype'] = eqtls.genotype.apply(_fdr_name_mapper)
    sns.histplot(
        x='pos_eqtl',
        hue='genotype',
        data=eqtls,
        bins=np.arange(0, chrom_sizes[chrom], 5e5),
        ax=ax,
        multiple="stack"
    )
    if chrom != 'Chr1':
        ax.legend_.remove()
axes[0].set_ylabel('eQTLs (count, stacked)')
axes[0].axvspan(22e6, 26e6, color=pal[2], alpha=0.1, zorder=0)
h = axes[0].get_ylim()[1]
axes[0].annotate('PSV1', xy=(24e6, h), ha='center')
axes[0].set_ylim(0, h * 1.1)
fig.supxlabel('eQTL position')
plt.tight_layout(pad=0.2)
#plt.savefig(os.path.join(snakemake.output[0], 'eqtl_hist.svg'))
plt.show()

# %%
def eqtl_plotter(gene_id, title=None):
    def _fdr_name_mapper(fdr_col_name):
        if fdr_col_name == 'lrt_fdr':
            return 'Combined'
        else:
            return fdr_col_name.rsplit('_', 1)[0].capitalize()

    gene_eqtl_res = (eqtl_res.query('gene_id == @gene_id')
                             .melt(id_vars=['chrom', 'start', 'end'],
                                   value_vars=[c for c in eqtl_res.columns if c.endswith('_fdr')],
                                   var_name='genotype',
                                   value_name='fdr'))
    if not len(gene_eqtl_res):
        raise ValueError('Gene was not tested')
    gene_eqtl_res = gene_eqtl_res.query('genotype != "wald_fdr"').assign(
        genotype=gene_eqtl_res.genotype.map(_fdr_name_mapper),
        nlog10_fdr=np.negative(np.log10(gene_eqtl_res.fdr))
    )
    order = gene_eqtl_res.query('genotype != "Combined"').genotype.unique()
    order = ['Combined'] + sorted(order)

    gene_pos = gene_locs.loc[gene_id]

    fig, axes = chrom_axes_boilerplate(chrom_sizes, figsize=(12, 3.5))
    for (chrom, chrom_eqtl_res), ax in zip(gene_eqtl_res.groupby('chrom'), axes):
        sns.lineplot(
            x='start',
            y='nlog10_fdr',
            hue='genotype',
            data=chrom_eqtl_res,
            drawstyle='steps-post',
            ax=ax,
            hue_order=order,
            palette = ['#252525'] + pal[:len(order) - 1]
        )
        if chrom == gene_pos.chrom:
            ax.axvline((gene_pos.start + gene_pos.end) // 2, ls='-', color='#252525', zorder=-1)
        for _, se in sig_eqtl.query('gene_id == @gene_id & chrom_eqtl == @chrom').iterrows():
            ax.axvline(se.pos_eqtl, ls='--', color='#777777', zorder=-1)
            ax.axvspan(se.start_eqtl, se.end_eqtl, color='#777777', zorder=-1, alpha=0.2)

    axes[0].set_ylabel('Negative log10 FDR')
    for ax in axes[:-1]:
        ax.legend_.remove()

    if title is None:
        title = gene_id
    fig.suptitle(title)

    plt.tight_layout(pad=0.2)
    return axes

# %%
def region_is_syntenic(syri_file, chrom, start, end, slop=1000, min_indel_size=100):
    syn_type = 'syntenic'
    n_snvs = 0
    for record in syri_file.fetch(chrom, max(0, start - slop), end + slop):
        sv_chrom, r_start, r_end, _, _, _, q_start, q_end, _, _, sv_type, _ = record.split()
        if sv_type in ('NOTAL', 'HDR', 'DUPAL', 'INVAL'):
            syn_type = 'non_syntenic'
            break
        elif sv_type == 'DEL':
            r_start, r_end = int(r_start), int(r_end)
            if (r_end - r_start) > min_indel_size:
                syn_type = 'large_indel'
        elif sv_type == 'INS':
            q_start, q_end = int(q_start), int(q_end)
            if (q_end - q_start) > min_indel_size:
                syn_type = 'large_indel'
        elif sv_type == 'SNP':
            n_snvs += 1
    return syn_type, n_snvs / (end - start) * 1000
        
@contextmanager
def synteny_mapper(syri_fns):
    syri_files = [pysam.TabixFile(syri_fn) for syri_fn in syri_fns]
    try:
        def _syn_mapper(*args, **kwargs):
            return [region_is_syntenic(sf, *args, **kwargs) for sf in syri_files]
        yield _syn_mapper
    finally:
        for sf in syri_files:
            sf.close()


def sv_mapper(gene_ids, gene_locs, syri_fns, genotypes, sig_eqtl):
    sv_res = []
    eqtl_types = []
    with synteny_mapper(syri_fns) as syn_mapper:
        for gene_id in gene_ids:
            chrom, start, end = gene_locs.loc[gene_id]
            if chrom in ('Mt', 'Pt'):
                continue
            synteny_classes = syn_mapper(chrom, start, end)
            syn_class = 'syntenic'
            n_snps = 0
            for s, n in synteny_classes:
                if s == 'non_syntenic':
                    syn_class = s
                    break
                elif s == 'large_indel':
                    syn_class = s
                n_snps += n
            n_snps = n_snps / len(syri_fns)
            gene_eqtls = sig_eqtl.query('gene_id == @gene_id')
            if not len(gene_eqtls):
                eqtl_type = 'no_eqtl'
            elif any(gene_eqtls.is_cis):
                eqtl_type = 'cis'
            else:
                eqtl_type = 'trans'
            sv_res.append([gene_id, chrom, start, end, eqtl_type, n_snps, syn_class])
    return pd.DataFrame(sv_res, columns=['gene_id', 'chrom', 'start', 'end', 'eqtl_type', 'snp_density', 'synteny_type'])

# %%
syri_fns = sorted(glob('annotation/diploid/vcf/col0__vs__*.syri.out.gz'))
genotypes = [os.path.split(sfn)[1].split('.')[0].split('__vs__')[1] for sfn in syri_fns]
genotypes
# Out:
# ['db1', 'kar1', 'ms0', 'rubezhnoe1', 'tsu0']

# %%
sv_data = sv_mapper(
    sorted(eqtl_res.gene_id.unique()),
    gene_locs, 
    syri_fns,
    genotypes,
    sig_eqtl
)
sv_data.head()
# Out:
#      gene_id chrom   start     end eqtl_type  snp_density synteny_type
# 0  AT1G01320  Chr1  121066  130577     trans     2.670592     syntenic
# 1  AT1G01340  Chr1  132269  135924   no_eqtl     5.143639  large_indel
# 2  AT1G01880  Chr1  306466  309541   no_eqtl     2.016260     syntenic
# 3  AT1G02140  Chr1  403099  404456   no_eqtl     9.874724     syntenic
# 4  AT1G02500  Chr1  518090  520495   no_eqtl    17.879418  large_indel

# %%
sv_data.eqtl_type.value_counts()
# Out:
# eqtl_type
# no_eqtl    885
# cis        168
# trans      106
# Name: count, dtype: int64

# %%
ct = pd.crosstab(sv_data.eqtl_type, sv_data.synteny_type)
stats.chi2_contingency(ct.loc[['trans', 'no_eqtl']])
# Out:
# Chi2ContingencyResult(statistic=2.696020538352238, pvalue=0.2597565924936383, dof=2, expected_freq=array([[ 20.00201816,   7.38042381,  78.61755802],
#        [166.99798184,  61.61957619, 656.38244198]]))

# %%
stats.chi2_contingency(ct.loc[['cis', 'no_eqtl']])
# Out:
# Chi2ContingencyResult(statistic=43.99147522601444, pvalue=2.8013832608738093e-10, dof=2, expected_freq=array([[ 33.02564103,  15.15669516, 119.81766382],
#        [173.97435897,  79.84330484, 631.18233618]]))

# %%
order=['no_eqtl', 'trans', 'cis']
hue_order=['syntenic', 'non_syntenic', 'large_indel']

ax = sns.countplot(
    x='eqtl_type',
    hue='synteny_type',
    data=sv_data,
    order=order,
    hue_order=hue_order,
)
perc = (sv_data.groupby('eqtl_type')
               .apply(lambda x: x.synteny_type.value_counts() / len(x) * 100)
               .unstack())
ylim = 0
for patch, (ho, o) in zip(ax.patches, it.product(hue_order, order)):
    p = perc.loc[(ho, o)]
    ax.annotate(
        text=f'{p:.1f}%',
        xy=(patch.get_x() + patch.get_width() / 2, patch.get_height()),
        xytext=(patch.get_x() + patch.get_width() / 2, patch.get_height() + 50),
        ha='center',
        fontsize=10,
        arrowprops=dict(facecolor='#252525', width=2, headwidth=5, headlength=5)
    )
    ylim = max(ylim, patch.get_height() + 100)
ax.legend(title='Synteny class', labels=['Syntenic', 'Rearranged', 'Indel > 100 bp'])
ax.set_xlabel('eQTL class')
ax.set_xticklabels(['No eQTL', 'Trans', 'Cis'])
ax.set_ylabel('Genes (count)')
ax.set_ylim(0, ylim)

plt.tight_layout()
plt.savefig(os.path.join(snakemake.output[0], 'eqtl_synteny_types.svg'))
plt.show()

# %%
sns.boxplot(x='eqtl_type', y='snp_density', data=sv_data, showfliers=False)
# Out:
# <Axes: xlabel='eqtl_type', ylabel='snp_density'>

# %%
stats.mannwhitneyu(sv_data.query('eqtl_type == "cis"').snp_density,
                   sv_data.query('eqtl_type == "no_eqtl"').snp_density)
# Out:
# MannwhitneyuResult(statistic=86518.0, pvalue=0.0007518600597329623)

# %%
for gene_id in ['AT3G16380', 'AT2G36660', 'AT5G09800']:
    eqtl_plotter(gene_id)
    #plt.savefig(os.path.join(snakemake.output[0], f'{gene_id}_eqtl_manhattan.svg'))
    plt.show()
