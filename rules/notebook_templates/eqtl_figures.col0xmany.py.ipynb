# %%
######## snakemake preamble start (automatically inserted, do not edit) ########
import sys; sys.path.extend(['/netscratch/dep_mercier/grp_schneeberger/bin/bin_matt/conda_envs/snakemake8/lib/python3.12/site-packages', '/netscratch/dep_mercier/grp_schneeberger/projects/Athal/Matt_snRNAseq_analysis/diploid_starsolo_pipeline/pipeline/../rules', '/netscratch/dep_mercier/grp_schneeberger/projects/Athal/Matt_snRNAseq_analysis/diploid_starsolo_pipeline/pipeline', '/netscratch/dep_mercier/grp_schneeberger/bin/bin_matt/conda_envs/snakemake8/bin', '/netscratch/dep_mercier/grp_schneeberger/bin/bin_matt/conda_envs/snakemake8/lib/python3.12', '/netscratch/dep_mercier/grp_schneeberger/bin/bin_matt/conda_envs/snakemake8/lib/python3.12/lib-dynload', '/netscratch/dep_mercier/grp_schneeberger/bin/bin_matt/conda_envs/snakemake8/lib/python3.12/site-packages', '/netscratch/dep_mercier/grp_schneeberger/projects/Athal/Matt_snRNAseq_analysis/diploid_starsolo_pipeline/rules/notebook_templates']); import pickle; snakemake = pickle.loads(b'\x80\x04\x95\xee\r\x00\x00\x00\x00\x00\x00\x8c\x10snakemake.script\x94\x8c\tSnakemake\x94\x93\x94)\x81\x94}\x94(\x8c\x05input\x94\x8c\x0csnakemake.io\x94\x8c\nInputFiles\x94\x93\x94)\x81\x94(\x8c7aligned_data/diploid/col0xmany.col0__vs__db1.sorted.bam\x94\x8c8aligned_data/diploid/col0xmany.col0__vs__kar1.sorted.bam\x94\x8c>aligned_data/diploid/col0xmany.col0__vs__rubezhnoe1.sorted.bam\x94\x8c7aligned_data/diploid/col0xmany.col0__vs__ms0.sorted.bam\x94\x8c8aligned_data/diploid/col0xmany.col0__vs__tsu0.sorted.bam\x94\x8c\x19../annotations/col0_cc.fa\x94\x8c\x15../annotations/db1.fa\x94\x8c\x16../annotations/kar1.fa\x94\x8c\x1c../annotations/rubezhnoe1.fa\x94\x8c\x15../annotations/ms0.fa\x94\x8c\x16../annotations/tsu0.fa\x94\x8c\x1a../annotations/col0_cc.gtf\x94\x8c\x16cb_stats/col0xmany.tsv\x94\x8c2cb_crossovers/col0xmany.col0__vs__db1.co_probs.tsv\x94\x8c3cb_crossovers/col0xmany.col0__vs__kar1.co_probs.tsv\x94\x8c9cb_crossovers/col0xmany.col0__vs__rubezhnoe1.co_probs.tsv\x94\x8c2cb_crossovers/col0xmany.col0__vs__ms0.co_probs.tsv\x94\x8c3cb_crossovers/col0xmany.col0__vs__tsu0.co_probs.tsv\x94\x8c\x19eqtls/col0xmany.eqtls.tsv\x94\x8c7aligned_data/diploid/col0xmany.col0__vs__db1_genecounts\x94\x8c8aligned_data/diploid/col0xmany.col0__vs__kar1_genecounts\x94\x8c>aligned_data/diploid/col0xmany.col0__vs__rubezhnoe1_genecounts\x94\x8c7aligned_data/diploid/col0xmany.col0__vs__ms0_genecounts\x94\x8c8aligned_data/diploid/col0xmany.col0__vs__tsu0_genecounts\x94\x8c3annotation/diploid/vcf/col0xmany.cellsnplite.vcf.gz\x94e}\x94(\x8c\x06_names\x94}\x94(\x8c\x04bams\x94K\x00K\x05\x86\x94\x8c\tref_fasta\x94K\x05N\x86\x94\x8c\x0eparent2_fastas\x94K\x06K\x0b\x86\x94\x8c\x03gtf\x94K\x0bN\x86\x94\x8c\x08cb_stats\x94K\x0cN\x86\x94\x8c\ncrossovers\x94K\rK\x12\x86\x94\x8c\x05eqtls\x94K\x12N\x86\x94\x8c\x05exprs\x94K\x13K\x18\x86\x94\x8c\x03vcf\x94K\x18N\x86\x94u\x8c\x12_allowed_overrides\x94]\x94(\x8c\x05index\x94\x8c\x04sort\x94eh:\x8c\tfunctools\x94\x8c\x07partial\x94\x93\x94h\x06\x8c\x19Namedlist._used_attribute\x94\x93\x94\x85\x94R\x94(h@)}\x94\x8c\x05_name\x94h:sNt\x94bh;h>h@\x85\x94R\x94(h@)}\x94hDh;sNt\x94bh&h\x06\x8c\tNamedlist\x94\x93\x94)\x81\x94(h\nh\x0bh\x0ch\rh\x0ee}\x94(h$}\x94h8]\x94(h:h;eh:h>h@\x85\x94R\x94(h@)}\x94hDh:sNt\x94bh;h>h@\x85\x94R\x94(h@)}\x94hDh;sNt\x94bubh(h\x0fh*hK)\x81\x94(h\x10h\x11h\x12h\x13h\x14e}\x94(h$}\x94h8]\x94(h:h;eh:h>h@\x85\x94R\x94(h@)}\x94hDh:sNt\x94bh;h>h@\x85\x94R\x94(h@)}\x94hDh;sNt\x94bubh,h\x15h.h\x16h0hK)\x81\x94(h\x17h\x18h\x19h\x1ah\x1be}\x94(h$}\x94h8]\x94(h:h;eh:h>h@\x85\x94R\x94(h@)}\x94hDh:sNt\x94bh;h>h@\x85\x94R\x94(h@)}\x94hDh;sNt\x94bubh2h\x1ch4hK)\x81\x94(h\x1dh\x1eh\x1fh h!e}\x94(h$}\x94h8]\x94(h:h;eh:h>h@\x85\x94R\x94(h@)}\x94hDh:sNt\x94bh;h>h@\x85\x94R\x94(h@)}\x94hDh;sNt\x94bubh6h"ub\x8c\x06output\x94h\x06\x8c\x0bOutputFiles\x94\x93\x94)\x81\x94\x8c\x1efigures/eqtl_figures_col0xmany\x94a}\x94(h$}\x94\x8c\x07figures\x94K\x00N\x86\x94sh8]\x94(h:h;eh:h>h@\x85\x94R\x94(h@)}\x94hDh:sNt\x94bh;h>h@\x85\x94R\x94(h@)}\x94hDh;sNt\x94bh\x83h\x80ub\x8c\x06params\x94h\x06\x8c\x06Params\x94\x93\x94)\x81\x94}\x94(h$}\x94h8]\x94(h:h;eh:h>h@\x85\x94R\x94(h@)}\x94hDh:sNt\x94bh;h>h@\x85\x94R\x94(h@)}\x94hDh;sNt\x94bub\x8c\twildcards\x94h\x06\x8c\tWildcards\x94\x93\x94)\x81\x94\x8c\tcol0xmany\x94a}\x94(h$}\x94\x8c\x04cond\x94K\x00N\x86\x94sh8]\x94(h:h;eh:h>h@\x85\x94R\x94(h@)}\x94hDh:sNt\x94bh;h>h@\x85\x94R\x94(h@)}\x94hDh;sNt\x94b\x8c\x04cond\x94h\xa1ub\x8c\x07threads\x94K\x01\x8c\tresources\x94h\x06\x8c\tResources\x94\x93\x94)\x81\x94(K\x01K\x01\x8c\x08/scratch\x94e}\x94(h$}\x94(\x8c\x06_cores\x94K\x00N\x86\x94\x8c\x06_nodes\x94K\x01N\x86\x94\x8c\x06tmpdir\x94K\x02N\x86\x94uh8]\x94(h:h;eh:h>h@\x85\x94R\x94(h@)}\x94hDh:sNt\x94bh;h>h@\x85\x94R\x94(h@)}\x94hDh;sNt\x94bh\xb8K\x01h\xbaK\x01h\xbch\xb5ub\x8c\x03log\x94h\x06\x8c\x03Log\x94\x93\x94)\x81\x94}\x94(h$}\x94h8]\x94(h:h;eh:h>h@\x85\x94R\x94(h@)}\x94hDh:sNt\x94bh;h>h@\x85\x94R\x94(h@)}\x94hDh;sNt\x94bub\x8c\x06config\x94}\x94(\x8c\x12reference_genotype\x94\x8c\x04col0\x94\x8c\x08datasets\x94}\x94(\x8c\tcol0xmany\x94}\x94(\x8c\x12reference_genotype\x94\x8c\x04col0\x94\x8c\x12parent2_accessions\x94]\x94(\x8c\x03db1\x94\x8c\x04kar1\x94\x8c\nrubezhnoe1\x94\x8c\x03ms0\x94\x8c\x04tsu0\x94eu\x8c\x08col0xdb1\x94}\x94(\x8c\x12reference_genotype\x94\x8c\x04col0\x94\x8c\x12parent2_accessions\x94]\x94\x8c\x03db1\x94au\x8c\x08db1xcol0\x94}\x94(\x8c\x12reference_genotype\x94\x8c\x03db1\x94\x8c\x12parent2_accessions\x94]\x94\x8c\x04col0\x94auu\x8c\x10genome_fasta_fns\x94}\x94(\x8c\x04col0\x94\x8c\x19../annotations/col0_cc.fa\x94\x8c\x03db1\x94\x8c\x15../annotations/db1.fa\x94\x8c\x04kar1\x94\x8c\x16../annotations/kar1.fa\x94\x8c\nrubezhnoe1\x94\x8c\x1c../annotations/rubezhnoe1.fa\x94\x8c\x03ms0\x94\x8c\x15../annotations/ms0.fa\x94\x8c\x04tsu0\x94\x8c\x16../annotations/tsu0.fa\x94u\x8c\x07gtf_fns\x94}\x94(\x8c\x04col0\x94\x8c\x1a../annotations/col0_cc.gtf\x94\x8c\x03db1\x94\x8c\x16../annotations/db1.gtf\x94u\x8c\x11barcode_whitelist\x94\x8c#../annotations/3M-february-2018.txt\x94\x8c\x1aorganellar_genome_fasta_fn\x94\x8c\x1c../annotations/organellar.fa\x94\x8c\x11organellar_gtf_fn\x94\x8c\x1d../annotations/organellar.gtf\x94u\x8c\x04rule\x94\x8c\x0ceqtl_figures\x94\x8c\x0fbench_iteration\x94N\x8c\tscriptdir\x94\x8c\x81/netscratch/dep_mercier/grp_schneeberger/projects/Athal/Matt_snRNAseq_analysis/diploid_starsolo_pipeline/rules/notebook_templates\x94ub.'); from snakemake.logging import logger; logger.printshellcmds = True; import os; os.chdir(r'/netscratch/dep_mercier/grp_schneeberger/projects/Athal/Matt_snRNAseq_analysis/diploid_starsolo_pipeline/pipeline');
######## snakemake preamble end #########

# %%
import sys
import os
import re
from copy import copy
from io import StringIO
from glob import glob
import random
import itertools as it
import warnings
from collections import Counter, defaultdict
from contextlib import contextmanager

import numpy as np
import pandas as pd
from scipy import stats
from sklearn.decomposition import PCA
from sklearn.mixture import GaussianMixture
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap, Normalize
from matplotlib.cm import ScalarMappable
from matplotlib.patches import Rectangle
from matplotlib_venn import venn3
import seaborn as sns

import pysam

sys.path.extend([os.path.abspath('../scripts/')])

from singlecell_snptools.io import parse_gene_positions, parse_gtf
from singlecell_snptools.eqtl import call_lod_peaks
from singlecell_snptools.exprs import read_mmformat, lognormalise_exprs
from singlecell_snptools.plot import chrom_axes_boilerplate, create_eqtl_plotter, create_haplotype_expression_plotter

## Default plotting params

# %matplotlib inline
sns.set(font='Arial')
plt.rcParams['svg.fonttype'] = 'none'
style = sns.axes_style('white')
style.update(sns.axes_style('ticks'))
style['xtick.major.size'] = 1
style['ytick.major.size'] = 1
sns.set(font_scale=1, style=style)
pal = sns.color_palette(['#0072b2', '#d55e00', '#009e73', '#f0e442', '#cc79a7', '#56b4e9', '#e69f00'])
cmap = ListedColormap(pal.as_hex())
sns.set_palette(pal)
sns.palplot(pal)
plt.show()

# %%
if not os.path.exists(snakemake.output[0]):
    os.mkdir(snakemake.output[0])

# %%
cb_stats = pd.read_csv(
    snakemake.input.cb_stats,
    header=0,
    index_col=0,
    sep='\t',
).query('cluster == "hq"')

cb_whitelist = sorted(cb_stats.index.tolist())

exprs_mat, _ = lognormalise_exprs(read_mmformat(
    snakemake.input.exprs,
    cb_whitelist
))

hap_probs = pd.concat((
    pd.read_csv(fn, sep='\t', header=[0, 1], index_col=[0, 1])
    for fn in snakemake.input.crossovers
), axis=0)
hap_probs.index = hap_probs.index.droplevel('fn_idx')

eqtl_res = pd.read_csv(snakemake.input.eqtls, sep='\t', dtype={'chrom': str})
chrom_sizes = eqtl_res.groupby('chrom').pos.max().to_dict()
sig_eqtl = call_lod_peaks(eqtl_res, snakemake.input.gtf)
eqtl_res.head()
# Out:
#   chrom  pos    gene_id  lod_score  lrt_pval  db1_pval  kar1_pval  ms0_pval  \
# 0  Chr1    0  AT1G01020     1.5540       1.0       1.0        1.0       1.0
# 1  Chr1    0  AT1G01100     0.8753       1.0       1.0        1.0       1.0
# 2  Chr1    0  AT1G01310     0.7707       1.0       1.0        1.0       1.0
# 3  Chr1    0  AT1G01320     4.3470       1.0       1.0        1.0       1.0
# 4  Chr1    0  AT1G01340     0.8177       1.0       1.0        1.0       1.0
#
#    rubezhnoe1_pval  tsu0_pval  ...  db1_x_cluster1_coef  db1_x_cluster2_coef  \
# 0              1.0        1.0  ...            -0.043570            -0.003198
# 1              1.0        1.0  ...            -0.033140             0.055650
# 2              1.0        1.0  ...            -0.045610            -0.036930
# 3              1.0        1.0  ...             0.081960             0.285600
# 4              1.0        1.0  ...            -0.001887            -0.074170
#
# ...

# %%
pca = PCA(n_components=10, svd_solver='arpack')
pca_proj = pca.fit_transform(exprs_mat.T)
pca_proj = pd.DataFrame(pca_proj, index=exprs_mat.columns, columns=[f'PC{i}' for i in range(1, 11)])

cluster_labels = pd.Series(GaussianMixture(covariance_type='spherical', n_components=2, random_state=1).fit(pca_proj).predict(pca_proj), index=pca_proj.index)
cb_stats['celltype_cluster'] = cluster_labels

# %%
fig, axes = chrom_axes_boilerplate(chrom_sizes, figsize=(10, 10), nrows='nchroms')
axes = axes[::-1]
chroms = list(chrom_sizes)

CIS_RANGE = 2e6
TRANS_RANGE = np.array([[25e6, 27e6]])

for i, j in it.product(range(len(chrom_sizes)), repeat=2):
    c_i, c_j = chroms[i], chroms[j]
    d = sig_eqtl.query('chrom_gene == @c_i & chrom_eqtl == @c_j')
    sns.scatterplot(
        x=d.pos_eqtl,
        y=d.pos_gene,
        hue=d.is_cis,
        size=d.lod_score,
        sizes=(5, 100),
        size_norm=(3, 50),
        hue_order=[False, True],
        palette=pal[:2],
        ax=axes[i][j],
    )
    axes[i][j].errorbar(
        x=d.pos_eqtl,
        y=d.pos_gene,
        xerr=[d.pos_eqtl - d.start_eqtl,
              d.end_eqtl - d.pos_eqtl],
        color='#777777',
        zorder=0,
        linestyle='None',
        marker='None',
        alpha=0.75
    )
    try:
        axes[i][j].legend_.remove()
    except:
        pass

    if i == j:
        axes[i][j].fill_between(
            x=[0, CIS_RANGE, chrom_sizes[c_j] - CIS_RANGE, chrom_sizes[c_j]],
            y1=[0, 0, chrom_sizes[c_i] - CIS_RANGE * 2, chrom_sizes[c_i] - CIS_RANGE],
            y2=[CIS_RANGE, CIS_RANGE * 2, chrom_sizes[c_i], chrom_sizes[c_i]],
            color=pal[1],
            alpha=0.1,
            zorder=2
        )
    
    axes[i][j].set_ylim(-500_000, chrom_sizes[c_i] + 500_000)
    axes[i][j].set_xlim(-500_000, chrom_sizes[c_j] + 500_000)

    if c_j == 'Chr1':
        for TR in TRANS_RANGE:
            if c_i != c_j:
                axes[i][j].axvspan(*TR, color=pal[2], alpha=0.2)
            else:
                axes[i][j].fill_between(
                    x=TR,
                    y1=[0, 0],
                    y2=TR - CIS_RANGE,
                    color=pal[2],
                    alpha=0.2
                )
                axes[i][j].fill_between(
                    x=TR,
                    y1=TR + CIS_RANGE,
                    y2=[chrom_sizes[c_i], chrom_sizes[c_i]],
                    color=pal[2],
                    alpha=0.2
                )

for ax, chrom in zip(axes[0], chroms):
    ax.set_xticks(np.arange(0, chrom_sizes[chrom], 1e7))
    ax.set_xticklabels([int(i // 1e6) for i in np.arange(0, chrom_sizes[chrom], 1e7)])
    ax.set_xlabel(f'{chrom} (Mb)')

for ax, chrom in zip(axes[:, 0], chroms):
    ax.set_yticks(np.arange(0, chrom_sizes[chrom], 1e7))
    ax.set_yticklabels([int(i // 1e6) for i in np.arange(0, chrom_sizes[chrom], 1e7)])
    ax.set_ylabel(f'{chrom} (Mb)')

fig.supxlabel('eQTL position')
fig.supylabel('Gene position')

plt.tight_layout(h_pad=0.1, w_pad=0.1)

plt.savefig(os.path.join(snakemake.output[0], 'eqtl_scatterplot.svg'))
plt.show()
# Out:
# /tmp/ipykernel_3509/1358395671.py:11: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(
# /tmp/ipykernel_3509/1358395671.py:11: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(
# /tmp/ipykernel_3509/1358395671.py:11: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(
# /tmp/ipykernel_3509/1358395671.py:11: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(
# /tmp/ipykernel_3509/1358395671.py:11: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(
# /tmp/ipykernel_3509/1358395671.py:11: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(

# %%
fig, axes = chrom_axes_boilerplate(chrom_sizes, figsize=(12, 3.5))
axes = axes.ravel()

for (chrom, eqtls), ax in zip(sig_eqtl.query('~is_cis').groupby('chrom_eqtl'), axes):
    eqtls = eqtls.melt(
        id_vars=['gene_id', 'pos_eqtl'],
        value_vars=['db1_pval',
                    'kar1_pval',
                    'ms0_pval',
                    'rubezhnoe1_pval',
                    'tsu0_pval'],
        var_name='genotype',
        value_name='pval',
    ).query('pval < 0.05')
    eqtls.genotype = eqtls.genotype.str.split('_', expand=True)[0].str.capitalize()
    sns.histplot(
        x='pos_eqtl',
        hue='genotype',
        hue_order=['Db1', 'Kar1', 'Ms0', 'Rubezhnoe1', 'Tsu0'],
        multiple='stack',
        data=eqtls,
        bins=np.arange(0, chrom_sizes[chrom], 5e5),
        ax=ax,
    )
    if chrom != 'Chr5':
        ax.legend_.remove()
axes[0].set_ylabel('eQTLs (count, stacked)')
axes[0].axvspan(25e6, 27e6, color=pal[2], alpha=0.1, zorder=0)
h = axes[0].get_ylim()[1]
axes[0].annotate('PSV1', xy=(26e6, h), ha='center')
axes[0].set_ylim(0, h * 1.1)
fig.supxlabel('eQTL position')
plt.tight_layout(pad=0.2)
plt.savefig(os.path.join(snakemake.output[0], 'eqtl_hist.svg'))
plt.show()

# %%
psv1_affected_genes = sig_eqtl.query('~is_cis & chrom_eqtl == "Chr1" & start_eqtl < 26.2e6 < end_eqtl').gene_id.unique()

# %%
psv1_affected_genes = sig_eqtl.query('~is_cis & chrom_eqtl == "Chr1" & start_eqtl < 26.2e6 < end_eqtl').gene_id.unique()

pag_gene_exprs = exprs_mat.loc[psv1_affected_genes]
av_exprs = pag_gene_exprs.T.groupby(pag_gene_exprs.columns.map(cb_stats.celltype_cluster)).mean().T
av_exprs = pd.melt(av_exprs.reset_index(), id_vars=['index'], value_vars=[0, 1], var_name='celltype', value_name='av_exprs')

fig, ax = plt.subplots(figsize=(5, 5))
sns.violinplot(x='celltype', y='av_exprs', data=av_exprs, order=[0, 1], cut=0)
ax.set_ylabel('Average log2 gene expression')
ax.set_xlabel('Cell-type')
ax.set_xticklabels(['Sperm', 'Vegetative'])
ax.set_title('Average expression of genes with PSV1 trans-eQTL')
plt.savefig(os.path.join(snakemake.output[0], 'avexprs_psv1.svg'))

# %%
gene_locs = parse_gene_positions(snakemake.input.gtf)

eqtl_plotter = create_eqtl_plotter(
    eqtl_res,
    sig_eqtl,
    gene_locs,
    col_mapper={'lrt_pval': 'Combined',
                'db1_pval': 'Db-1',
                'kar1_pval': 'Kar-1',
                'ms0_pval': 'Ms-0',
                'rubezhnoe1_pval': 'Rubezhnoe-1',
                'tsu0_pval': 'Tsu-0'},
    palette=['#252525'] + pal[:5]
)

# %%
eqtl_plotter('AT1G31990', title='Haplotypes correlating with the expression of AT1G31990')
plt.savefig(os.path.join(snakemake.output[0],'AT1G31990_manhattan_block_plot.svg'))
plt.show()

# %%
eqtl_plotter('AT4G31400', title='Haplotypes correlating with the expression of CTF7 (AT4G31400)')
plt.savefig(os.path.join(snakemake.output[0],'CTF7_manhattan_block_plot.svg'))
plt.show()

# %%
eqtl_plotter('AT2G36660', title='Haplotypes correlating with the expression of PAB7 (AT2G36660)')
plt.savefig(os.path.join(snakemake.output[0],'PAB7_manhattan_block_plot.svg'))
plt.show()

# %%
eqtl_plotter('AT3G16380', title='Haplotypes correlating with the expression of PAB6 (AT3G16380)')
plt.savefig(os.path.join(snakemake.output[0],'PAB6_manhattan_block_plot.svg'))
plt.show()

# %%
eqtl_plotter('AT3G12510', title='Haplotypes correlating with the expression of AT3G12510')
plt.savefig(os.path.join(snakemake.output[0],'AT3G12510_manhattan_block_plot.svg'))
plt.show()

# %%
eqtl_plotter('AT1G50490', title='Haplotypes correlating with the expression of AT1G50490')
plt.show()

# %%
haplotype_plotter = create_haplotype_expression_plotter(
    exprs_mat, eqtl_res, hap_probs, cb_stats, gene_locs,
)

# %%
ax = haplotype_plotter(
    'AT1G31990',
    x='genotype',
    hue='haplotype',
    haplotype_hue='cis',
    cut=0,
    scale='width',
    order=['db1', 'kar1', 'ms0', 'rubezhnoe1', 'tsu0'],
    figsize=(7, 5)
)
ax.set_title('Expression of AT1G31990 separated by cis-haplotype')
plt.savefig(os.path.join(snakemake.output[0],'AT1G31990_haplotype_expression.svg'))
plt.show()

# %%
ax = haplotype_plotter(
    'AT4G31400',
    x='genotype',
    hue='haplotype',
    haplotype_hue='cis',
    cut=0,
    scale='width',
    order=['db1', 'kar1', 'ms0', 'rubezhnoe1', 'tsu0'],
    hue_order=['Parent 1', 'Parent 2'],
    figsize=(7, 5)
)
ax.set_title('Expression of CTF7 separated by cis-haplotype')
plt.savefig(os.path.join(snakemake.output[0],'CTF7_haplotype_expression.svg'))
plt.show()

# %%
ax = haplotype_plotter(
    'AT3G12510',
    x='genotype',
    hue='haplotype',
    haplotype_hue='cis',
    cut=0,
    scale='width',
    order=['db1', 'kar1', 'ms0', 'rubezhnoe1', 'tsu0'],
    hue_order=['Parent 1', 'Parent 2'],
    figsize=(7, 5)
)
ax.set_title('Expression of AT3G12510 separated by cis-haplotype')
plt.savefig(os.path.join(snakemake.output[0],'AT3G12510_haplotype_expression.svg'))
plt.show()

# %%
ax = haplotype_plotter(
    'AT1G50490',
    x='genotype',
    hue='haplotype',
    haplotype_hue='best_hit',
    cut=0,
    scale='width',
    order=['db1', 'kar1', 'ms0', 'rubezhnoe1', 'tsu0']
)
ax.set_title('Expression of UBC20 separated by PSV1 haplotype')
#plt.savefig(os.path.join(snakemake.output[0],'PAB7_haplotype_expression.svg'))
plt.show()

# %%
ax = haplotype_plotter(
    'AT1G50490',
    x='genotype',
    hue='haplotype',
    haplotype_hue='cis',
    cut=0,
    scale='width',
    order=['db1', 'kar1', 'ms0', 'rubezhnoe1', 'tsu0']
)
ax.set_title('Expression of UBC20 separated by PSV1 haplotype')
#plt.savefig(os.path.join(snakemake.output[0],'PAB7_haplotype_expression.svg'))
plt.show()

# %%
ax = haplotype_plotter(
    'AT3G16380',
    x='genotype',
    hue='haplotype',
    haplotype_hue='best_hit',
    cut=0,
    scale='width',
    order=['db1', 'kar1', 'ms0', 'rubezhnoe1', 'tsu0']
)
ax.set_title('Expression of PAB6 separated by PSV1 haplotype')
plt.savefig(os.path.join(snakemake.output[0],'PAB6_haplotype_expression.svg'))
plt.show()

# %%
def region_is_syntenic(syri_file, chrom, start, end, slop=1000, min_indel_size=100):
    syn_type = 'syntenic'
    n_snvs = 0
    for record in syri_file.fetch(chrom, max(0, start - slop), end + slop):
        sv_chrom, r_start, r_end, _, _, _, q_start, q_end, _, _, sv_type, _ = record.split()
        if sv_type in ('NOTAL', 'HDR', 'DUPAL', 'INVAL', 'TRANSAL', 'INVDPAL', 'INVTRAL', 'CPG', 'CPL'):
            syn_type = 'non_syntenic'
            break
        elif sv_type == 'DEL':
            r_start, r_end = int(r_start), int(r_end)
            if (r_end - r_start) > min_indel_size:
                syn_type = 'large_indel'
        elif sv_type == 'INS':
            q_start, q_end = int(q_start), int(q_end)
            if (q_end - q_start) > min_indel_size:
                syn_type = 'large_indel'
        elif sv_type == 'SNP':
            n_snvs += 1
    return syn_type, n_snvs / (end - start) * 1000
        
@contextmanager
def synteny_mapper(syri_fns):
    syri_files = [pysam.TabixFile(syri_fn) for syri_fn in syri_fns]
    try:
        def _syn_mapper(*args, **kwargs):
            return [region_is_syntenic(sf, *args, **kwargs) for sf in syri_files]
        yield _syn_mapper
    finally:
        for sf in syri_files:
            sf.close()


def sv_mapper(gene_ids, gene_locs, syri_fns, genotypes, sig_eqtl):
    sv_res = []
    eqtl_types = []
    with synteny_mapper(syri_fns) as syn_mapper:
        for gene_id in gene_ids:
            try:
                chrom, strand, invs = gene_locs[gene_id]
            except KeyError:
                continue
            start, end = invs[0]
            if chrom in ('Mt', 'Pt'):
                continue
            synteny_classes = syn_mapper(chrom, start, end)
            syn_class = 'syntenic'
            n_snps = 0
            for s, n in synteny_classes:
                if s == 'non_syntenic':
                    syn_class = s
                    break
                elif s == 'large_indel':
                    syn_class = s
                n_snps += n
            n_snps = n_snps / len(syri_fns)
            gene_eqtls = sig_eqtl.query('gene_id == @gene_id')
            if not len(gene_eqtls):
                eqtl_type = 'no_eqtl'
            elif any(gene_eqtls.is_cis):
                eqtl_type = 'cis'
            else:
                eqtl_type = 'trans'
            sv_res.append([gene_id, chrom, start, end, eqtl_type, n_snps, syn_class])
    return pd.DataFrame(sv_res, columns=['gene_id', 'chrom', 'start', 'end', 'eqtl_type', 'snp_density', 'synteny_type'])

# %%
syri_fns = sorted(glob('annotation/diploid/vcf/col0__vs__*.syri.out.gz'))
genotypes = [os.path.split(sfn)[1].split('.')[0].split('__vs__')[1] for sfn in syri_fns]
genotypes
# Out:
# ['db1', 'kar1', 'ms0', 'rubezhnoe1', 'tsu0']

# %%
sv_data = sv_mapper(
    sorted(eqtl_res.gene_id.unique()),
    dict(zip(*parse_gtf(snakemake.input.gtf, quant_type='gene_full'))),
    syri_fns,
    genotypes,
    sig_eqtl
)
sv_data.head()
# Out:
# [E::get_intv] Failed to parse TBX_GENERIC, was wrong -p [type] used?
# The offending line was: "-	-	-	-	-	Chr1	1	1063	NOTAL218	-	NOTAL	-"
# [E::get_intv] Failed to parse TBX_GENERIC, was wrong -p [type] used?
# The offending line was: "-	-	-	-	-	Chr1	11375181	11384831	NOTAL219	-	NOTAL	-"
# [E::get_intv] Failed to parse TBX_GENERIC, was wrong -p [type] used?
# The offending line was: "-	-	-	-	-	Chr1	1	1177	NOTAL204	-	NOTAL	-"
# [E::get_intv] Failed to parse TBX_GENERIC, was wrong -p [type] used?
# The offending line was: "-	-	-	-	-	Chr1	13252566	13253836	NOTAL240	-	NOTAL	-"
# [E::get_intv] Failed to parse TBX_GENERIC, was wrong -p [type] used?
# The offending line was: "-	-	-	-	-	Chr1	1	3120	NOTAL205	-	NOTAL	-"
# [E::get_intv] Failed to parse TBX_GENERIC, was wrong -p [type] used?
# The offending line was: "-	-	-	-	-	Chr1	1	1063	NOTAL218	-	NOTAL	-"
# [E::get_intv] Failed to parse TBX_GENERIC, was wrong -p [type] used?
# ...

# %%
stats.chi2_contingency([[1490, 109 + 444], [108, 83 + 37]])
# Out:
# Chi2ContingencyResult(statistic=63.05913521522908, pvalue=2.0059288759216124e-15, dof=1, expected_freq=array([[1437.5667107,  605.4332893],
#        [ 160.4332893,   67.5667107]]))

# %%
sig_eqtl.query('~is_cis & chrom_eqtl == "Chr1" & start_eqtl < 26.2e6 < end_eqtl')
# Out:
#     chrom_eqtl    gene_id  lod_score      lrt_pval  db1_pval  kar1_pval  \
# 0         Chr1  AT1G01320     10.010  6.406000e-05  0.017860        1.0
# 3         Chr1  AT1G04010      6.759  3.253000e-02  1.000000        1.0
# 5         Chr1  AT1G04880     15.810  5.912000e-10  0.001959        1.0
# 6         Chr1  AT1G05380      8.639  8.944000e-04  1.000000        1.0
# 10        Chr1  AT1G09815      7.582  6.909000e-03  1.000000        1.0
# ..         ...        ...        ...           ...       ...        ...
# 333       Chr1  AT5G54680      7.545  7.369000e-03  0.253200        1.0
# 334       Chr1  AT5G54970      7.004  1.993000e-02  1.000000        1.0
# 336       Chr1  AT5G59550      9.073  4.070000e-04  1.000000        1.0
# 338       Chr1  AT5G59690      9.694  1.204000e-04  0.000500        1.0
# 344       Chr1  AT5G64480     10.040  8.353000e-05  1.000000        1.0
#
#      ms0_pval  rubezhnoe1_pval  tsu0_pval  db1_coef  ...  \
# ...

# %%
69 / 117
# Out:
# 0.5897435897435898

# %%
order=['no_eqtl', 'trans', 'cis']
hue_order=['syntenic', 'non_syntenic', 'large_indel']

ax = sns.barplot(
    x='eqtl_type',
    y='proportion',
    hue='synteny_type',
    data=sv_data.groupby('eqtl_type')['synteny_type'].value_counts(normalize=True).mul(100).reset_index(),
    order=order,
    hue_order=hue_order,
)
perc = (sv_data.groupby('eqtl_type')
               .apply(lambda x: x.synteny_type.value_counts() / len(x) * 100)
               .unstack())
ylim = 0
for patch, (ho, o) in zip(ax.patches, it.product(hue_order, order)):
    p = perc.loc[(ho, o)]
    ax.annotate(
        text=f'{p:.1f}%',
        xy=(patch.get_x() + patch.get_width() / 2, patch.get_height()),
        xytext=(patch.get_x() + patch.get_width() / 2, patch.get_height() + 10),
        ha='center',
        fontsize=10,
        arrowprops=dict(facecolor='#252525', width=2, headwidth=5, headlength=5)
    )
    ylim = max(ylim, patch.get_height() + 20)
ax.legend(title='Synteny class', labels=['Syntenic', 'Rearranged', 'Indel > 100 bp'])
ax.set_xlabel('eQTL class')
ax.set_xticklabels(['No eQTL', 'Trans', 'Cis'])
ax.set_ylabel('Genes (percentage of eQTL class)')
ax.set_ylim(0, ylim)

plt.tight_layout()
plt.savefig(os.path.join(snakemake.output[0], 'eqtl_synteny_types.svg'))
plt.show()

# %%
fig, ax = plt.subplots()
venn3(
    [set(sig_eqtl.query('~is_cis & chrom_eqtl == "Chr1" & start_eqtl < 26.2e6 < end_eqtl').gene_id.unique()),
     set(sig_eqtl.query('~is_cis & chrom_eqtl == "Chr1" & start_eqtl < 26.2e6 < end_eqtl & db1_pval < 0.05').gene_id.unique()),
     set(sig_eqtl.query('~is_cis & chrom_eqtl == "Chr1" & start_eqtl < 26.2e6 < end_eqtl & rubezhnoe1_pval < 0.05').gene_id.unique())],
    set_labels=['All genotypes', 'Db-1', 'Rubezhnoe-1'],
    set_colors=['#BBBBBB', pal[0], pal[3]],
    alpha=1
)
ax.set_title('PSV1 trans-eQTL genes')
plt.savefig(os.path.join(snakemake.output[0], 'transeqtl_overlap.svg'))
plt.show()
